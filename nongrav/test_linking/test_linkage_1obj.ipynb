# %%
## In this notebook, we will attempt to find the magnitude of nongravitational 
## acceleration for which heliolinc and link_purify will no longer recognize 
## a given object as a single body.

# %%
## first, import the necessary modules

import os 
import sys
import numpy as np
import pandas as pd
import subprocess
import sorcha

# %%
## create the Sorcha input files for one single object 
## the object could be a normal object like Pratchett, 
## or one that already displays nongravs. Favor the former.

## note that there are two ways to approach this overall:

## 1 - Run the ENTIRE PIPELINE for each object with each nongrav setting,
##   - creating different input files each time

## 2 - Figure out a way to determine what object the linkages in a given 
##   - heliolinx output correspond to, whether using orbital element
##   - comparison or some other way. 

## in any case, I believe that the best course of action is to create
## separate input files for each magnitude of nongrav -- i.e., one input 
## file where the A1 magnitude is 10^-6, one input file where the A1 magnitude
## is 10^-5, etc., for each object in the file.

# %%
## define our filepaths and filename stems

## filepath for sorcha input and output files
sfpath = "/home/ellie/research/lsst/sorcha_output/127005pratchett_new/"

## filename stems for the orbit files and other files
fname_orb = "pratchett_orb"
fname_stem = "pratchett"

## object ID
obj_id = "127005Pratchett"

## location of Sorcha config file
config_fpath = "Rubin_full_footprint.ini"

## location of pointing database file for Sorcha
pointing_db_path = "/home/ellie/src/sorcha/sorcha/demo/baseline_v2.0_1yr.db"

## location of Earth location file for HelioLinC
earth1day_path = '/home/ellie/research/lsst/heliolinc_files/Earth1day2020s_02a.csv'

## location of ObsCodes file for HelioLinC
obscodes_path = '/home/ellie/research/lsst/heliolinc_files/ObsCodes.html'

## location of colformat file for HelioLinC
colformat_path = '/home/ellie/research/lsst/heliolinc_files/colformat.txt'

## location of hypothesis file for HelioLinC
hypo_path = '/home/ellie/research/lsst/sorcha_output/127005pratchett_new/hihyp00b_mb.txt'

## location of kep2cart.py program
k2c_path = '/home/ellie/research/lsst/lsst_seti/nongrav/sorcha_ng'

## import the kep2cart module
kep_dir = os.path.abspath(k2c_path)
sys.path.insert(0, kep_dir)

from kep2cart import kep2cart as k2c

# %%
## create the Sorcha inputs

## first, the orbits file(s)
## read in the Keplerian orbits file first and convert to Cartesian

k2c("{0}_kep.csv".format(fname_orb), "{0}{1}_cart.csv".format(sfpath, fname_orb))
# Out:
# New Cartesian orbits file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_cart.csv written.

# %%
## generate the nongravitational orbits files
nongravs = np.logspace(start=-12, stop=3, num=16, base=10) 

df = pd.read_csv("{0}{1}_cart.csv".format(sfpath, fname_orb))
df['FORMAT'] = 'NONGRAV'
df['a1'] = 0.0
df['a2'] = 0.0
df['a3'] = 0.0
df['model'] = 'ASTEROID'
epoch = df.pop('epochMJD_TDB')
df.insert(12, 'epochMJD_TDB', epoch)

orb_files = ["{0}{1}_cart.csv".format(sfpath, fname_orb)]

for i in range(len(nongravs)):
    df1 = df.copy()
    df1['a1'] = nongravs[i]
    df1_fname = "{0}{1}_ng_a1_{2}.csv".format(sfpath, fname_orb, np.log10(nongravs[i]))
    df1.to_csv(df1_fname, index=False)

    df2 = df.copy()
    df2['a2'] = nongravs[i]
    df2_fname = "{0}{1}_ng_a2_{2}.csv".format(sfpath, fname_orb, np.log10(nongravs[i]))
    df2.to_csv(df2_fname, index=False)

    df3 = df.copy()
    df3['a3'] = nongravs[i]
    df3_fname = "{0}{1}_ng_a3_{2}.csv".format(sfpath, fname_orb, np.log10(nongravs[i]))
    df3.to_csv(df3_fname, index=False)

    orb_files.append(df1_fname)
    orb_files.append(df2_fname)
    orb_files.append(df3_fname)  

df_orbfiles = pd.DataFrame()
df_orbfiles['orb_files'] = orb_files

# %%
## generate Physical Parameters file using placeholder values
## (these are not the correct values, need to fix)

df_phy = pd.DataFrame()
df_phy['ObjID'] = [obj_id]
df_phy['H_r'] = [5.63]
df_phy['u-r'] = [1.508064] #[2.55]
df_phy['g-r'] = [0.293132] #[0.92]
df_phy['i-r'] = [-0.292761] #[-0.38]
df_phy['z-r'] = [-0.298066] #[-0.59]
df_phy['y-r'] = [0.302652] #[-0.70]
df_phy['GS'] = [0.15]

df_phy.to_csv("{0}{1}_phy.csv".format(sfpath, fname_stem), index=False)

# %%
## create a list of output filename stems for Sorcha

ofnames = []

for idx in range(len(orb_files)):

    ## define the output filename stem (no extension)
    ofname = orb_files[idx].replace("_orb", "") 
    ofname = ofname.split('/')[-1]
    ofname = ofname.split('.')[:-1]
    ofname = '.'.join(ofname)

    ofnames.append(ofname)

print(orb_files[0])
print(ofnames[0])

df_orbfiles['of_names'] = ofnames
df_orbfiles.to_csv('orb_files2.csv', index=False)
# Out:
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_cart.csv
# pratchett_cart

# %%
## run Sorcha on each file
lst = range(len(orb_files))
#print(lst[28:][0])

for i in lst:#range(len(orb_files)):
    print(orb_files[i])
    print(ofnames[i])
    subprocess.run(["sorcha","run","-c", config_fpath,"-p","{0}_phy.csv".format(fname_stem),"--orbits",\
                    orb_files[i],"--pd",pointing_db_path,"-o",sfpath,"-t",sfpath+ofnames[i],\
                    "--st","{0}{1}_stats".format(sfpath,ofnames[i])])

    print('\n{0} out of {1} ({2} %) complete'.format(i+1, len(orb_files), 100*round((i+1)/len(orb_files), 2)))
# Out:
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_cart.csv
# pratchett_cart
#
# 1 out of 49 (2.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a1_-12.0.csv
# pratchett_ng_a1_-12.0
# 1.0 1.0 2.0 5.093 0.0
#
# 2 out of 49 (4.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a2_-12.0.csv
# pratchett_ng_a2_-12.0
# 1.0 1.0 2.0 5.093 0.0
#
# 3 out of 49 (6.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a3_-12.0.csv
# pratchett_ng_a3_-12.0
# 1.0 1.0 2.0 5.093 0.0
#
# 4 out of 49 (8.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a1_-11.0.csv
# pratchett_ng_a1_-11.0
# 1.0 1.0 2.0 5.093 0.0
#
# 5 out of 49 (10.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a2_-11.0.csv
# pratchett_ng_a2_-11.0
# 1.0 1.0 2.0 5.093 0.0
#
# 6 out of 49 (12.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a3_-11.0.csv
# pratchett_ng_a3_-11.0
# 1.0 1.0 2.0 5.093 0.0
#
# 7 out of 49 (14.000000000000002 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a1_-10.0.csv
# pratchett_ng_a1_-10.0
# 1.0 1.0 2.0 5.093 0.0
#
# 8 out of 49 (16.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a2_-10.0.csv
# pratchett_ng_a2_-10.0
# 1.0 1.0 2.0 5.093 0.0
#
# 9 out of 49 (18.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a3_-10.0.csv
# pratchett_ng_a3_-10.0
# 1.0 1.0 2.0 5.093 0.0
#
# 10 out of 49 (20.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a1_-9.0.csv
# pratchett_ng_a1_-9.0
# 1.0 1.0 2.0 5.093 0.0
#
# 11 out of 49 (22.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a2_-9.0.csv
# pratchett_ng_a2_-9.0
# 1.0 1.0 2.0 5.093 0.0
#
# 12 out of 49 (24.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a3_-9.0.csv
# pratchett_ng_a3_-9.0
# 1.0 1.0 2.0 5.093 0.0
#
# 13 out of 49 (27.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a1_-8.0.csv
# pratchett_ng_a1_-8.0
# 1.0 1.0 2.0 5.093 0.0
#
# 14 out of 49 (28.999999999999996 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a2_-8.0.csv
# pratchett_ng_a2_-8.0
# 1.0 1.0 2.0 5.093 0.0
#
# 15 out of 49 (31.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a3_-8.0.csv
# pratchett_ng_a3_-8.0
# 1.0 1.0 2.0 5.093 0.0
#
# 16 out of 49 (33.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a1_-7.0.csv
# pratchett_ng_a1_-7.0
# 1.0 1.0 2.0 5.093 0.0
#
# 17 out of 49 (35.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a2_-7.0.csv
# pratchett_ng_a2_-7.0
# 1.0 1.0 2.0 5.093 0.0
#
# 18 out of 49 (37.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a3_-7.0.csv
# pratchett_ng_a3_-7.0
# 1.0 1.0 2.0 5.093 0.0
#
# 19 out of 49 (39.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a1_-6.0.csv
# pratchett_ng_a1_-6.0
# 1.0 1.0 2.0 5.093 0.0
#
# 20 out of 49 (41.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a2_-6.0.csv
# pratchett_ng_a2_-6.0
# 1.0 1.0 2.0 5.093 0.0
#
# 21 out of 49 (43.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a3_-6.0.csv
# pratchett_ng_a3_-6.0
# 1.0 1.0 2.0 5.093 0.0
#
# 22 out of 49 (45.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a1_-5.0.csv
# pratchett_ng_a1_-5.0
# 1.0 1.0 2.0 5.093 0.0
#
# 23 out of 49 (47.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a2_-5.0.csv
# pratchett_ng_a2_-5.0
# 1.0 1.0 2.0 5.093 0.0
#
# 24 out of 49 (49.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a3_-5.0.csv
# pratchett_ng_a3_-5.0
# 1.0 1.0 2.0 5.093 0.0
#
# 25 out of 49 (51.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a1_-4.0.csv
# pratchett_ng_a1_-4.0
# 1.0 1.0 2.0 5.093 0.0
#
# 26 out of 49 (53.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a2_-4.0.csv
# pratchett_ng_a2_-4.0
# 1.0 1.0 2.0 5.093 0.0
#
# 27 out of 49 (55.00000000000001 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a3_-4.0.csv
# pratchett_ng_a3_-4.0
# 1.0 1.0 2.0 5.093 0.0
#
# 28 out of 49 (56.99999999999999 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a1_-3.0.csv
# pratchett_ng_a1_-3.0
# 1.0 1.0 2.0 5.093 0.0
#
# 29 out of 49 (59.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a2_-3.0.csv
# pratchett_ng_a2_-3.0
# 1.0 1.0 2.0 5.093 0.0
#
# 30 out of 49 (61.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a3_-3.0.csv
# pratchett_ng_a3_-3.0
# 1.0 1.0 2.0 5.093 0.0
#
# 31 out of 49 (63.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a1_-2.0.csv
# pratchett_ng_a1_-2.0
# 1.0 1.0 2.0 5.093 0.0
#
# 32 out of 49 (65.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a2_-2.0.csv
# pratchett_ng_a2_-2.0
# 1.0 1.0 2.0 5.093 0.0
#
# 33 out of 49 (67.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a3_-2.0.csv
# pratchett_ng_a3_-2.0
# 1.0 1.0 2.0 5.093 0.0
#
# 34 out of 49 (69.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a1_-1.0.csv
# pratchett_ng_a1_-1.0
# 1.0 1.0 2.0 5.093 0.0
#
# 35 out of 49 (71.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a2_-1.0.csv
# pratchett_ng_a2_-1.0
# 1.0 1.0 2.0 5.093 0.0
#
# 36 out of 49 (73.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a3_-1.0.csv
# pratchett_ng_a3_-1.0
# 1.0 1.0 2.0 5.093 0.0
#
# 37 out of 49 (76.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a1_0.0.csv
# pratchett_ng_a1_0.0
# 1.0 1.0 2.0 5.093 0.0
#
# 38 out of 49 (78.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a2_0.0.csv
# pratchett_ng_a2_0.0
# 1.0 1.0 2.0 5.093 0.0
#
# 39 out of 49 (80.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a3_0.0.csv
# pratchett_ng_a3_0.0
# 1.0 1.0 2.0 5.093 0.0
#
# 40 out of 49 (82.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a1_1.0.csv
# pratchett_ng_a1_1.0
# 1.0 1.0 2.0 5.093 0.0
#
# 41 out of 49 (84.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a2_1.0.csv
# pratchett_ng_a2_1.0
# 1.0 1.0 2.0 5.093 0.0
#
# 42 out of 49 (86.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a3_1.0.csv
# pratchett_ng_a3_1.0
# 1.0 1.0 2.0 5.093 0.0
#
# 43 out of 49 (88.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a1_2.0.csv
# pratchett_ng_a1_2.0
# 1.0 1.0 2.0 5.093 0.0
#
# 44 out of 49 (90.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a2_2.0.csv
# pratchett_ng_a2_2.0
# 1.0 1.0 2.0 5.093 0.0
#
# 45 out of 49 (92.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a3_2.0.csv
# pratchett_ng_a3_2.0
# 1.0 1.0 2.0 5.093 0.0
#
# 46 out of 49 (94.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a1_3.0.csv
# pratchett_ng_a1_3.0
# 1.0 1.0 2.0 5.093 0.0
#
# 47 out of 49 (96.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a2_3.0.csv
# pratchett_ng_a2_3.0
# 1.0 1.0 2.0 5.093 0.0
#
# 48 out of 49 (98.0 %) complete
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_orb_ng_a3_3.0.csv
# pratchett_ng_a3_3.0
# 1.0 1.0 2.0 5.093 0.0
#
# 49 out of 49 (100.0 %) complete

# %%
## shorten the Sorcha output to one month of detections, as heliolinc seems to balk
## at anything much longer, according to Aren

arr = lst
out_fnames = []
missing = []
new_ofnames = []

for j in arr:

    if os.path.isfile("{0}{1}.csv".format(sfpath, ofnames[j])):
        ## insert logic to check if file exists -- if so, do the following
        ## (else, print "{fname} does not exist, skipping")
        df_sorcha = pd.read_csv("{0}{1}.csv".format(sfpath, ofnames[j]))
        start_date = df_sorcha['fieldMJD_TAI'][0]
        end_date = start_date+30

        df_sorcha_30d = df_sorcha[df_sorcha['fieldMJD_TAI'] <= end_date]
        df_sorcha_30d.to_csv("{0}{1}_30days.csv".format(sfpath, ofnames[j]), index=False)

        ## create an input file from the Sorcha
        ## output that is compatible with make_tracklets
        ## ( this same code can be found in 
        ## /lsst_seti/nongrav/heliolinc/create_maketracklets_input.py )
    
        fname = "{0}{1}_30days.csv".format(sfpath, ofnames[j])
        out_fname = "{0}{1}_30days_cmi.csv".format(sfpath, ofnames[j])

        df = pd.read_csv(fname)
        nrows = len(df['ObjID'])
        df['ObsCode'] = np.full((nrows, 1), 'I11')

        df.to_csv(out_fname, index=False)

        print(out_fname)
        out_fnames.append(out_fname)
        new_ofnames.append(ofnames[j])
        
    else:
        print("Warning: {0}{1}.csv does not exist.".format(sfpath, ofnames[j]))
        missing.append("{0}{1}.csv".format(sfpath, ofnames[j]))

df_missing = pd.DataFrame()
df_missing['missing_files'] = missing
df_missing.to_csv('missing_files.csv', index=False)

## reassign ofnames so it only includes non-missing files,
## to avoid issues later
ofnames = new_ofnames
# Out:
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_cart_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a1_-12.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a2_-12.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a3_-12.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a1_-11.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a2_-11.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a3_-11.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a1_-10.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a2_-10.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a3_-10.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a1_-9.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a2_-9.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a3_-9.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a1_-8.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a2_-8.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a3_-8.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a1_-7.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a2_-7.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a3_-7.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a1_-6.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a2_-6.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a3_-6.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a1_-5.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a2_-5.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a3_-5.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a1_-4.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a2_-4.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a3_-4.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a1_-3.0_30days_cmi.csv
# Warning: /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a2_-3.0.csv does not exist.
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a3_-3.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a1_-2.0_30days_cmi.csv
# Warning: /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a2_-2.0.csv does not exist.
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a3_-2.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a1_-1.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a2_-1.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a3_-1.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a1_0.0_30days_cmi.csv
# Warning: /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a2_0.0.csv does not exist.
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a3_0.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a1_1.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a2_1.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a3_1.0_30days_cmi.csv
# Warning: /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a1_2.0.csv does not exist.
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a2_2.0_30days_cmi.csv
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a3_2.0_30days_cmi.csv
# Warning: /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a1_3.0.csv does not exist.
# Warning: /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a2_3.0.csv does not exist.
# /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a3_3.0_30days_cmi.csv

# %%
## run make_tracklets

for k in range(len(out_fnames)):

    subprocess.run(['make_tracklets', '-dets', out_fnames[k], '-earth', earth1day_path, \
                   '-obscode', obscodes_path, '-colformat', colformat_path,'-outimgs', \
                   '{0}outim_{1}.txt'.format(sfpath, ofnames[k]), \
                   '-pairdets', '{0}pairdets_{1}.csv'.format(sfpath, ofnames[k]),\
                   '-tracklets', '{0}tracklets_{1}.csv'.format(sfpath, ofnames[k]), \
                   '-trk2det', '{0}trk2det_{1}.csv'.format(sfpath, ofnames[k])])
# Out:
# Checking out argv[1] = -dets.
# Checking out argv[3] = -earth.
# Checking out argv[5] = -obscode.
# Checking out argv[7] = -colformat.
# Checking out argv[9] = -outimgs.
# Checking out argv[11] = -pairdets.
# Checking out argv[13] = -tracklets.
# Checking out argv[15] = -trk2det.
#
# Input detection file is called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_cart_30days_cmi.csv
#
# No input image file specified: image catalog will be generated internally.
# column formatting file = /home/ellie/research/lsst/heliolinc_files/colformat.txt
# Observatory code file /home/ellie/research/lsst/heliolinc_files/ObsCodes.html
# Output image file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_cart.txt
# Output paired detection file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_cart.csv
# Output tracklet file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/tracklets_pratchett_cart.csv
# Output tracklet-to-detection mapping file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/trk2det_pratchett_cart.csv
# Heliocentric ephemeris file for the Earth: /home/ellie/research/lsst/heliolinc_files/Earth1day2020s_02a.csv
# Defaulting to image radius = 2 degrees.
# Using simpler, less memory-efficient algorithm: matchrad and trkfrac parameters have no effect
# Defaulting to max time interval = 1.5 hours.
# Defaulting to min time interval = 0.000277778 hours.
# Defaulting to min angular velocity = 0 deg/day.
# Defaulting to maximum angular velocity = 1.5 deg/day.
# Defaulting to minimum number of points per tracklet = 2
# Defaulting to maximum number of points for a non-exclusive tracklet = 2
# Defaulting to time offset (added to obs times to get UTC) = 0 seconds
# Defaulting to minimum tracklet length = 0 arcsec.
# Defulting to maximum tracklet Great Circle residual = 0.5 arcsec.
# WARNING: only 7 column specifications, of 14 expected, were read from column format file /home/ellie/research/lsst/heliolinc_files/colformat.txt.
# Column specifications:
# IDCOL 1
# MJDCOL 2
# RACOL 5
# DECCOL 6
# MAGCOL 9
# BANDCOL 8
# OBSCODECOL 16
# Read 2662 lines from observatory code file /home/ellie/research/lsst/heliolinc_files/ObsCodes.html
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_cart_30days_cmi.csv read successfully to the end.
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_cart_30days_cmi.csv read successfully to the end.
# Finished reading heliocentric ephemeris file /home/ellie/research/lsst/heliolinc_files/Earth1day2020s_02a.csv for the Earth.
# 18 unique images were identified.
# Given our total of 18 detections,
# we have 1 detections per image, on average
# In main, exposure time was corrected for 18 out of 18 images
# Writing output image catalog /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_cart.txt with 18 lines
# Inside make_tracklets8
# Configuration parameters for new make_tracklets:
# Min. number of tracklet points: 2
# Time-tolerance for matching detections on the same image: 5.78704e-06 days (0.5 seconds)
# Maximum angular velocity: 1.5 deg/day
# Minimum angular velocity: 0 deg/day
# Minimum angular arc: 0 arcsec
# Maximum inter-image time interval: 0.0625 days (90 minutes)
# Minimum inter-image time interval: 1.15741e-05 days (0.0166667 minutes)
# Image radius: 2 degrees
# Maximum Great Circle Residual for tracklets with more than two points: 0.5 arcsec
# Maximum non-exclusive tracklet length is 2 points
# find_pairs is sanity-checking indvecs
# Sanity-check finished
# make_tracklets is sanity-checking indvecs
# Sanity-check finished
# 3 overlapping images found for image 0; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 1; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 2; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 3; current time is Mon Jan 26 04:37:45 2026
#
# 0 overlapping images found for image 4; current time is Mon Jan 26 04:37:45 2026
#
# 1 overlapping images found for image 5; current time is Mon Jan 26 04:37:45 2026
#
# 1 overlapping images found for image 6; current time is Mon Jan 26 04:37:45 2026
#
# 0 overlapping images found for image 7; current time is Mon Jan 26 04:37:45 2026
#
# 2 overlapping images found for image 8; current time is Mon Jan 26 04:37:45 2026
#
# 2 overlapping images found for image 9; current time is Mon Jan 26 04:37:45 2026
#
# 2 overlapping images found for image 10; current time is Mon Jan 26 04:37:45 2026
#
# 0 overlapping images found for image 11; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 12; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 13; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 14; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 15; current time is Mon Jan 26 04:37:45 2026
#
# 1 overlapping images found for image 16; current time is Mon Jan 26 04:37:45 2026
#
# 1 overlapping images found for image 17; current time is Mon Jan 26 04:37:45 2026
#
# merge_pairs is sanity-checking indvecs
# Sanity-check finished
# merge_pairs3 finished OK
# Output image catalog /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_cart.txt, with 18 lines, has been written
# Writing paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_cart.csv with 15 lines
# Writing tracklet file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/tracklets_pratchett_cart.csv with 5 lines
# Writing trk2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/trk2det_pratchett_cart.csv with 15 lines
# Checking out argv[1] = -dets.
# Checking out argv[3] = -earth.
# Checking out argv[5] = -obscode.
# Checking out argv[7] = -colformat.
# Checking out argv[9] = -outimgs.
# Checking out argv[11] = -pairdets.
# Checking out argv[13] = -tracklets.
# Checking out argv[15] = -trk2det.
#
# Input detection file is called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a1_-12.0_30days_cmi.csv
#
# No input image file specified: image catalog will be generated internally.
# column formatting file = /home/ellie/research/lsst/heliolinc_files/colformat.txt
# Observatory code file /home/ellie/research/lsst/heliolinc_files/ObsCodes.html
# Output image file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a1_-12.0.txt
# Output paired detection file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a1_-12.0.csv
# Output tracklet file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/tracklets_pratchett_ng_a1_-12.0.csv
# Output tracklet-to-detection mapping file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/trk2det_pratchett_ng_a1_-12.0.csv
# Heliocentric ephemeris file for the Earth: /home/ellie/research/lsst/heliolinc_files/Earth1day2020s_02a.csv
# Defaulting to image radius = 2 degrees.
# Using simpler, less memory-efficient algorithm: matchrad and trkfrac parameters have no effect
# Defaulting to max time interval = 1.5 hours.
# Defaulting to min time interval = 0.000277778 hours.
# Defaulting to min angular velocity = 0 deg/day.
# Defaulting to maximum angular velocity = 1.5 deg/day.
# Defaulting to minimum number of points per tracklet = 2
# Defaulting to maximum number of points for a non-exclusive tracklet = 2
# Defaulting to time offset (added to obs times to get UTC) = 0 seconds
# Defaulting to minimum tracklet length = 0 arcsec.
# Defulting to maximum tracklet Great Circle residual = 0.5 arcsec.
# WARNING: only 7 column specifications, of 14 expected, were read from column format file /home/ellie/research/lsst/heliolinc_files/colformat.txt.
# Column specifications:
# IDCOL 1
# MJDCOL 2
# RACOL 5
# DECCOL 6
# MAGCOL 9
# BANDCOL 8
# OBSCODECOL 16
# Read 2662 lines from observatory code file /home/ellie/research/lsst/heliolinc_files/ObsCodes.html
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a1_-12.0_30days_cmi.csv read successfully to the end.
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a1_-12.0_30days_cmi.csv read successfully to the end.
# Finished reading heliocentric ephemeris file /home/ellie/research/lsst/heliolinc_files/Earth1day2020s_02a.csv for the Earth.
# 18 unique images were identified.
# Given our total of 18 detections,
# we have 1 detections per image, on average
# In main, exposure time was corrected for 18 out of 18 images
# Writing output image catalog /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a1_-12.0.txt with 18 lines
# Inside make_tracklets8
# Configuration parameters for new make_tracklets:
# Min. number of tracklet points: 2
# Time-tolerance for matching detections on the same image: 5.78704e-06 days (0.5 seconds)
# Maximum angular velocity: 1.5 deg/day
# Minimum angular velocity: 0 deg/day
# Minimum angular arc: 0 arcsec
# Maximum inter-image time interval: 0.0625 days (90 minutes)
# Minimum inter-image time interval: 1.15741e-05 days (0.0166667 minutes)
# Image radius: 2 degrees
# Maximum Great Circle Residual for tracklets with more than two points: 0.5 arcsec
# Maximum non-exclusive tracklet length is 2 points
# find_pairs is sanity-checking indvecs
# Sanity-check finished
# make_tracklets is sanity-checking indvecs
# Sanity-check finished
# 3 overlapping images found for image 0; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 1; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 2; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 3; current time is Mon Jan 26 04:37:45 2026
#
# 0 overlapping images found for image 4; current time is Mon Jan 26 04:37:45 2026
#
# 1 overlapping images found for image 5; current time is Mon Jan 26 04:37:45 2026
#
# 1 overlapping images found for image 6; current time is Mon Jan 26 04:37:45 2026
#
# 0 overlapping images found for image 7; current time is Mon Jan 26 04:37:45 2026
#
# 2 overlapping images found for image 8; current time is Mon Jan 26 04:37:45 2026
#
# 2 overlapping images found for image 9; current time is Mon Jan 26 04:37:45 2026
#
# 2 overlapping images found for image 10; current time is Mon Jan 26 04:37:45 2026
#
# 0 overlapping images found for image 11; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 12; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 13; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 14; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 15; current time is Mon Jan 26 04:37:45 2026
#
# 1 overlapping images found for image 16; current time is Mon Jan 26 04:37:45 2026
#
# 1 overlapping images found for image 17; current time is Mon Jan 26 04:37:45 2026
#
# merge_pairs is sanity-checking indvecs
# Sanity-check finished
# merge_pairs3 finished OK
# Output image catalog /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a1_-12.0.txt, with 18 lines, has been written
# Writing paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a1_-12.0.csv with 15 lines
# Writing tracklet file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/tracklets_pratchett_ng_a1_-12.0.csv with 5 lines
# Writing trk2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/trk2det_pratchett_ng_a1_-12.0.csv with 15 lines
# Checking out argv[1] = -dets.
# Checking out argv[3] = -earth.
# Checking out argv[5] = -obscode.
# Checking out argv[7] = -colformat.
# Checking out argv[9] = -outimgs.
# Checking out argv[11] = -pairdets.
# Checking out argv[13] = -tracklets.
# Checking out argv[15] = -trk2det.
#
# Input detection file is called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a2_-12.0_30days_cmi.csv
#
# No input image file specified: image catalog will be generated internally.
# column formatting file = /home/ellie/research/lsst/heliolinc_files/colformat.txt
# Observatory code file /home/ellie/research/lsst/heliolinc_files/ObsCodes.html
# Output image file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a2_-12.0.txt
# Output paired detection file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a2_-12.0.csv
# Output tracklet file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/tracklets_pratchett_ng_a2_-12.0.csv
# Output tracklet-to-detection mapping file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/trk2det_pratchett_ng_a2_-12.0.csv
# Heliocentric ephemeris file for the Earth: /home/ellie/research/lsst/heliolinc_files/Earth1day2020s_02a.csv
# Defaulting to image radius = 2 degrees.
# Using simpler, less memory-efficient algorithm: matchrad and trkfrac parameters have no effect
# Defaulting to max time interval = 1.5 hours.
# Defaulting to min time interval = 0.000277778 hours.
# Defaulting to min angular velocity = 0 deg/day.
# Defaulting to maximum angular velocity = 1.5 deg/day.
# Defaulting to minimum number of points per tracklet = 2
# Defaulting to maximum number of points for a non-exclusive tracklet = 2
# Defaulting to time offset (added to obs times to get UTC) = 0 seconds
# Defaulting to minimum tracklet length = 0 arcsec.
# Defulting to maximum tracklet Great Circle residual = 0.5 arcsec.
# WARNING: only 7 column specifications, of 14 expected, were read from column format file /home/ellie/research/lsst/heliolinc_files/colformat.txt.
# Column specifications:
# IDCOL 1
# MJDCOL 2
# RACOL 5
# DECCOL 6
# MAGCOL 9
# BANDCOL 8
# OBSCODECOL 16
# Read 2662 lines from observatory code file /home/ellie/research/lsst/heliolinc_files/ObsCodes.html
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a2_-12.0_30days_cmi.csv read successfully to the end.
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a2_-12.0_30days_cmi.csv read successfully to the end.
# Finished reading heliocentric ephemeris file /home/ellie/research/lsst/heliolinc_files/Earth1day2020s_02a.csv for the Earth.
# 18 unique images were identified.
# Given our total of 18 detections,
# we have 1 detections per image, on average
# In main, exposure time was corrected for 18 out of 18 images
# Writing output image catalog /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a2_-12.0.txt with 18 lines
# Inside make_tracklets8
# Configuration parameters for new make_tracklets:
# Min. number of tracklet points: 2
# Time-tolerance for matching detections on the same image: 5.78704e-06 days (0.5 seconds)
# Maximum angular velocity: 1.5 deg/day
# Minimum angular velocity: 0 deg/day
# Minimum angular arc: 0 arcsec
# Maximum inter-image time interval: 0.0625 days (90 minutes)
# Minimum inter-image time interval: 1.15741e-05 days (0.0166667 minutes)
# Image radius: 2 degrees
# Maximum Great Circle Residual for tracklets with more than two points: 0.5 arcsec
# Maximum non-exclusive tracklet length is 2 points
# find_pairs is sanity-checking indvecs
# Sanity-check finished
# make_tracklets is sanity-checking indvecs
# Sanity-check finished
# 3 overlapping images found for image 0; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 1; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 2; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 3; current time is Mon Jan 26 04:37:45 2026
#
# 0 overlapping images found for image 4; current time is Mon Jan 26 04:37:45 2026
#
# 1 overlapping images found for image 5; current time is Mon Jan 26 04:37:45 2026
#
# 1 overlapping images found for image 6; current time is Mon Jan 26 04:37:45 2026
#
# 0 overlapping images found for image 7; current time is Mon Jan 26 04:37:45 2026
#
# 2 overlapping images found for image 8; current time is Mon Jan 26 04:37:45 2026
#
# 2 overlapping images found for image 9; current time is Mon Jan 26 04:37:45 2026
#
# 2 overlapping images found for image 10; current time is Mon Jan 26 04:37:45 2026
#
# 0 overlapping images found for image 11; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 12; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 13; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 14; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 15; current time is Mon Jan 26 04:37:45 2026
#
# 1 overlapping images found for image 16; current time is Mon Jan 26 04:37:45 2026
#
# 1 overlapping images found for image 17; current time is Mon Jan 26 04:37:45 2026
#
# merge_pairs is sanity-checking indvecs
# Sanity-check finished
# merge_pairs3 finished OK
# Output image catalog /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a2_-12.0.txt, with 18 lines, has been written
# Writing paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a2_-12.0.csv with 15 lines
# Writing tracklet file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/tracklets_pratchett_ng_a2_-12.0.csv with 5 lines
# Writing trk2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/trk2det_pratchett_ng_a2_-12.0.csv with 15 lines
# Checking out argv[1] = -dets.
# Checking out argv[3] = -earth.
# Checking out argv[5] = -obscode.
# Checking out argv[7] = -colformat.
# Checking out argv[9] = -outimgs.
# Checking out argv[11] = -pairdets.
# Checking out argv[13] = -tracklets.
# Checking out argv[15] = -trk2det.
#
# Input detection file is called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a3_-12.0_30days_cmi.csv
#
# No input image file specified: image catalog will be generated internally.
# column formatting file = /home/ellie/research/lsst/heliolinc_files/colformat.txt
# Observatory code file /home/ellie/research/lsst/heliolinc_files/ObsCodes.html
# Output image file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a3_-12.0.txt
# Output paired detection file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a3_-12.0.csv
# Output tracklet file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/tracklets_pratchett_ng_a3_-12.0.csv
# Output tracklet-to-detection mapping file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/trk2det_pratchett_ng_a3_-12.0.csv
# Heliocentric ephemeris file for the Earth: /home/ellie/research/lsst/heliolinc_files/Earth1day2020s_02a.csv
# Defaulting to image radius = 2 degrees.
# Using simpler, less memory-efficient algorithm: matchrad and trkfrac parameters have no effect
# Defaulting to max time interval = 1.5 hours.
# Defaulting to min time interval = 0.000277778 hours.
# Defaulting to min angular velocity = 0 deg/day.
# Defaulting to maximum angular velocity = 1.5 deg/day.
# Defaulting to minimum number of points per tracklet = 2
# Defaulting to maximum number of points for a non-exclusive tracklet = 2
# Defaulting to time offset (added to obs times to get UTC) = 0 seconds
# Defaulting to minimum tracklet length = 0 arcsec.
# Defulting to maximum tracklet Great Circle residual = 0.5 arcsec.
# WARNING: only 7 column specifications, of 14 expected, were read from column format file /home/ellie/research/lsst/heliolinc_files/colformat.txt.
# Column specifications:
# IDCOL 1
# MJDCOL 2
# RACOL 5
# DECCOL 6
# MAGCOL 9
# BANDCOL 8
# OBSCODECOL 16
# Read 2662 lines from observatory code file /home/ellie/research/lsst/heliolinc_files/ObsCodes.html
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a3_-12.0_30days_cmi.csv read successfully to the end.
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a3_-12.0_30days_cmi.csv read successfully to the end.
# Finished reading heliocentric ephemeris file /home/ellie/research/lsst/heliolinc_files/Earth1day2020s_02a.csv for the Earth.
# 18 unique images were identified.
# Given our total of 18 detections,
# we have 1 detections per image, on average
# In main, exposure time was corrected for 18 out of 18 images
# Writing output image catalog /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a3_-12.0.txt with 18 lines
# Inside make_tracklets8
# Configuration parameters for new make_tracklets:
# Min. number of tracklet points: 2
# Time-tolerance for matching detections on the same image: 5.78704e-06 days (0.5 seconds)
# Maximum angular velocity: 1.5 deg/day
# Minimum angular velocity: 0 deg/day
# Minimum angular arc: 0 arcsec
# Maximum inter-image time interval: 0.0625 days (90 minutes)
# Minimum inter-image time interval: 1.15741e-05 days (0.0166667 minutes)
# Image radius: 2 degrees
# Maximum Great Circle Residual for tracklets with more than two points: 0.5 arcsec
# Maximum non-exclusive tracklet length is 2 points
# find_pairs is sanity-checking indvecs
# Sanity-check finished
# make_tracklets is sanity-checking indvecs
# Sanity-check finished
# 3 overlapping images found for image 0; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 1; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 2; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 3; current time is Mon Jan 26 04:37:45 2026
#
# 0 overlapping images found for image 4; current time is Mon Jan 26 04:37:45 2026
#
# 1 overlapping images found for image 5; current time is Mon Jan 26 04:37:45 2026
#
# 1 overlapping images found for image 6; current time is Mon Jan 26 04:37:45 2026
#
# 0 overlapping images found for image 7; current time is Mon Jan 26 04:37:45 2026
#
# 2 overlapping images found for image 8; current time is Mon Jan 26 04:37:45 2026
#
# 2 overlapping images found for image 9; current time is Mon Jan 26 04:37:45 2026
#
# 2 overlapping images found for image 10; current time is Mon Jan 26 04:37:45 2026
#
# 0 overlapping images found for image 11; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 12; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 13; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 14; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 15; current time is Mon Jan 26 04:37:45 2026
#
# 1 overlapping images found for image 16; current time is Mon Jan 26 04:37:45 2026
#
# 1 overlapping images found for image 17; current time is Mon Jan 26 04:37:45 2026
#
# merge_pairs is sanity-checking indvecs
# Sanity-check finished
# merge_pairs3 finished OK
# Output image catalog /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a3_-12.0.txt, with 18 lines, has been written
# Writing paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a3_-12.0.csv with 15 lines
# Writing tracklet file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/tracklets_pratchett_ng_a3_-12.0.csv with 5 lines
# Writing trk2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/trk2det_pratchett_ng_a3_-12.0.csv with 15 lines
# Checking out argv[1] = -dets.
# Checking out argv[3] = -earth.
# Checking out argv[5] = -obscode.
# Checking out argv[7] = -colformat.
# Checking out argv[9] = -outimgs.
# Checking out argv[11] = -pairdets.
# Checking out argv[13] = -tracklets.
# Checking out argv[15] = -trk2det.
#
# Input detection file is called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a1_-11.0_30days_cmi.csv
#
# No input image file specified: image catalog will be generated internally.
# column formatting file = /home/ellie/research/lsst/heliolinc_files/colformat.txt
# Observatory code file /home/ellie/research/lsst/heliolinc_files/ObsCodes.html
# Output image file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a1_-11.0.txt
# Output paired detection file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a1_-11.0.csv
# Output tracklet file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/tracklets_pratchett_ng_a1_-11.0.csv
# Output tracklet-to-detection mapping file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/trk2det_pratchett_ng_a1_-11.0.csv
# Heliocentric ephemeris file for the Earth: /home/ellie/research/lsst/heliolinc_files/Earth1day2020s_02a.csv
# Defaulting to image radius = 2 degrees.
# Using simpler, less memory-efficient algorithm: matchrad and trkfrac parameters have no effect
# Defaulting to max time interval = 1.5 hours.
# Defaulting to min time interval = 0.000277778 hours.
# Defaulting to min angular velocity = 0 deg/day.
# Defaulting to maximum angular velocity = 1.5 deg/day.
# Defaulting to minimum number of points per tracklet = 2
# Defaulting to maximum number of points for a non-exclusive tracklet = 2
# Defaulting to time offset (added to obs times to get UTC) = 0 seconds
# Defaulting to minimum tracklet length = 0 arcsec.
# Defulting to maximum tracklet Great Circle residual = 0.5 arcsec.
# WARNING: only 7 column specifications, of 14 expected, were read from column format file /home/ellie/research/lsst/heliolinc_files/colformat.txt.
# Column specifications:
# IDCOL 1
# MJDCOL 2
# RACOL 5
# DECCOL 6
# MAGCOL 9
# BANDCOL 8
# OBSCODECOL 16
# Read 2662 lines from observatory code file /home/ellie/research/lsst/heliolinc_files/ObsCodes.html
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a1_-11.0_30days_cmi.csv read successfully to the end.
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a1_-11.0_30days_cmi.csv read successfully to the end.
# Finished reading heliocentric ephemeris file /home/ellie/research/lsst/heliolinc_files/Earth1day2020s_02a.csv for the Earth.
# 18 unique images were identified.
# Given our total of 18 detections,
# we have 1 detections per image, on average
# In main, exposure time was corrected for 18 out of 18 images
# Writing output image catalog /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a1_-11.0.txt with 18 lines
# Inside make_tracklets8
# Configuration parameters for new make_tracklets:
# Min. number of tracklet points: 2
# Time-tolerance for matching detections on the same image: 5.78704e-06 days (0.5 seconds)
# Maximum angular velocity: 1.5 deg/day
# Minimum angular velocity: 0 deg/day
# Minimum angular arc: 0 arcsec
# Maximum inter-image time interval: 0.0625 days (90 minutes)
# Minimum inter-image time interval: 1.15741e-05 days (0.0166667 minutes)
# Image radius: 2 degrees
# Maximum Great Circle Residual for tracklets with more than two points: 0.5 arcsec
# Maximum non-exclusive tracklet length is 2 points
# find_pairs is sanity-checking indvecs
# Sanity-check finished
# make_tracklets is sanity-checking indvecs
# Sanity-check finished
# 3 overlapping images found for image 0; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 1; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 2; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 3; current time is Mon Jan 26 04:37:45 2026
#
# 0 overlapping images found for image 4; current time is Mon Jan 26 04:37:45 2026
#
# 1 overlapping images found for image 5; current time is Mon Jan 26 04:37:45 2026
#
# 1 overlapping images found for image 6; current time is Mon Jan 26 04:37:45 2026
#
# 0 overlapping images found for image 7; current time is Mon Jan 26 04:37:45 2026
#
# 2 overlapping images found for image 8; current time is Mon Jan 26 04:37:45 2026
#
# 2 overlapping images found for image 9; current time is Mon Jan 26 04:37:45 2026
#
# 2 overlapping images found for image 10; current time is Mon Jan 26 04:37:45 2026
#
# 0 overlapping images found for image 11; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 12; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 13; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 14; current time is Mon Jan 26 04:37:45 2026
#
# 3 overlapping images found for image 15; current time is Mon Jan 26 04:37:46 2026
#
# 1 overlapping images found for image 16; current time is Mon Jan 26 04:37:46 2026
#
# 1 overlapping images found for image 17; current time is Mon Jan 26 04:37:46 2026
#
# merge_pairs is sanity-checking indvecs
# Sanity-check finished
# merge_pairs3 finished OK
# Output image catalog /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a1_-11.0.txt, with 18 lines, has been written
# Writing paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a1_-11.0.csv with 15 lines
# Writing tracklet file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/tracklets_pratchett_ng_a1_-11.0.csv with 5 lines
# Writing trk2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/trk2det_pratchett_ng_a1_-11.0.csv with 15 lines
# Checking out argv[1] = -dets.
# Checking out argv[3] = -earth.
# Checking out argv[5] = -obscode.
# Checking out argv[7] = -colformat.
# Checking out argv[9] = -outimgs.
# Checking out argv[11] = -pairdets.
# Checking out argv[13] = -tracklets.
# Checking out argv[15] = -trk2det.
#
# Input detection file is called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a2_-11.0_30days_cmi.csv
#
# No input image file specified: image catalog will be generated internally.
# column formatting file = /home/ellie/research/lsst/heliolinc_files/colformat.txt
# Observatory code file /home/ellie/research/lsst/heliolinc_files/ObsCodes.html
# Output image file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a2_-11.0.txt
# Output paired detection file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a2_-11.0.csv
# Output tracklet file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/tracklets_pratchett_ng_a2_-11.0.csv
# Output tracklet-to-detection mapping file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/trk2det_pratchett_ng_a2_-11.0.csv
# Heliocentric ephemeris file for the Earth: /home/ellie/research/lsst/heliolinc_files/Earth1day2020s_02a.csv
# Defaulting to image radius = 2 degrees.
# Using simpler, less memory-efficient algorithm: matchrad and trkfrac parameters have no effect
# Defaulting to max time interval = 1.5 hours.
# Defaulting to min time interval = 0.000277778 hours.
# Defaulting to min angular velocity = 0 deg/day.
# Defaulting to maximum angular velocity = 1.5 deg/day.
# Defaulting to minimum number of points per tracklet = 2
# Defaulting to maximum number of points for a non-exclusive tracklet = 2
# Defaulting to time offset (added to obs times to get UTC) = 0 seconds
# Defaulting to minimum tracklet length = 0 arcsec.
# Defulting to maximum tracklet Great Circle residual = 0.5 arcsec.
# WARNING: only 7 column specifications, of 14 expected, were read from column format file /home/ellie/research/lsst/heliolinc_files/colformat.txt.
# Column specifications:
# IDCOL 1
# MJDCOL 2
# RACOL 5
# DECCOL 6
# MAGCOL 9
# BANDCOL 8
# OBSCODECOL 16
# Read 2662 lines from observatory code file /home/ellie/research/lsst/heliolinc_files/ObsCodes.html
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a2_-11.0_30days_cmi.csv read successfully to the end.
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a2_-11.0_30days_cmi.csv read successfully to the end.
# Finished reading heliocentric ephemeris file /home/ellie/research/lsst/heliolinc_files/Earth1day2020s_02a.csv for the Earth.
# 18 unique images were identified.
# Given our total of 18 detections,
# we have 1 detections per image, on average
# In main, exposure time was corrected for 18 out of 18 images
# Writing output image catalog /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a2_-11.0.txt with 18 lines
# Inside make_tracklets8
# Configuration parameters for new make_tracklets:
# Min. number of tracklet points: 2
# Time-tolerance for matching detections on the same image: 5.78704e-06 days (0.5 seconds)
# Maximum angular velocity: 1.5 deg/day
# Minimum angular velocity: 0 deg/day
# Minimum angular arc: 0 arcsec
# Maximum inter-image time interval: 0.0625 days (90 minutes)
# Minimum inter-image time interval: 1.15741e-05 days (0.0166667 minutes)
# Image radius: 2 degrees
# Maximum Great Circle Residual for tracklets with more than two points: 0.5 arcsec
# Maximum non-exclusive tracklet length is 2 points
# find_pairs is sanity-checking indvecs
# Sanity-check finished
# make_tracklets is sanity-checking indvecs
# Sanity-check finished
# 3 overlapping images found for image 0; current time is Mon Jan 26 04:37:46 2026
#
# 3 overlapping images found for image 1; current time is Mon Jan 26 04:37:46 2026
#
# 3 overlapping images found for image 2; current time is Mon Jan 26 04:37:46 2026
#
# 3 overlapping images found for image 3; current time is Mon Jan 26 04:37:46 2026
#
# 0 overlapping images found for image 4; current time is Mon Jan 26 04:37:46 2026
#
# 1 overlapping images found for image 5; current time is Mon Jan 26 04:37:46 2026
#
# 1 overlapping images found for image 6; current time is Mon Jan 26 04:37:46 2026
#
# 0 overlapping images found for image 7; current time is Mon Jan 26 04:37:46 2026
#
# 2 overlapping images found for image 8; current time is Mon Jan 26 04:37:46 2026
#
# 2 overlapping images found for image 9; current time is Mon Jan 26 04:37:46 2026
#
# 2 overlapping images found for image 10; current time is Mon Jan 26 04:37:46 2026
#
# 0 overlapping images found for image 11; current time is Mon Jan 26 04:37:46 2026
#
# 3 overlapping images found for image 12; current time is Mon Jan 26 04:37:46 2026
#
# 3 overlapping images found for image 13; current time is Mon Jan 26 04:37:46 2026
#
# 3 overlapping images found for image 14; current time is Mon Jan 26 04:37:46 2026
#
# 3 overlapping images found for image 15; current time is Mon Jan 26 04:37:46 2026
#
# 1 overlapping images found for image 16; current time is Mon Jan 26 04:37:46 2026
#
# 1 overlapping images found for image 17; current time is Mon Jan 26 04:37:46 2026
#
# merge_pairs is sanity-checking indvecs
# Sanity-check finished
# merge_pairs3 finished OK
# Output image catalog /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a2_-11.0.txt, with 18 lines, has been written
# Writing paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a2_-11.0.csv with 15 lines
# Writing tracklet file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/tracklets_pratchett_ng_a2_-11.0.csv with 5 lines
# Writing trk2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/trk2det_pratchett_ng_a2_-11.0.csv with 15 lines
# Checking out argv[1] = -dets.
# Checking out argv[3] = -earth.
# Checking out argv[5] = -obscode.
# Checking out argv[7] = -colformat.
# Checking out argv[9] = -outimgs.
# Checking out argv[11] = -pairdets.
# Checking out argv[13] = -tracklets.
# Checking out argv[15] = -trk2det.
#
# Input detection file is called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a3_-11.0_30days_cmi.csv
#
# No input image file specified: image catalog will be generated internally.
# column formatting file = /home/ellie/research/lsst/heliolinc_files/colformat.txt
# Observatory code file /home/ellie/research/lsst/heliolinc_files/ObsCodes.html
# Output image file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a3_-11.0.txt
# Output paired detection file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a3_-11.0.csv
# Output tracklet file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/tracklets_pratchett_ng_a3_-11.0.csv
# Output tracklet-to-detection mapping file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/trk2det_pratchett_ng_a3_-11.0.csv
# Heliocentric ephemeris file for the Earth: /home/ellie/research/lsst/heliolinc_files/Earth1day2020s_02a.csv
# Defaulting to image radius = 2 degrees.
# Using simpler, less memory-efficient algorithm: matchrad and trkfrac parameters have no effect
# Defaulting to max time interval = 1.5 hours.
# Defaulting to min time interval = 0.000277778 hours.
# Defaulting to min angular velocity = 0 deg/day.
# Defaulting to maximum angular velocity = 1.5 deg/day.
# Defaulting to minimum number of points per tracklet = 2
# Defaulting to maximum number of points for a non-exclusive tracklet = 2
# Defaulting to time offset (added to obs times to get UTC) = 0 seconds
# Defaulting to minimum tracklet length = 0 arcsec.
# Defulting to maximum tracklet Great Circle residual = 0.5 arcsec.
# WARNING: only 7 column specifications, of 14 expected, were read from column format file /home/ellie/research/lsst/heliolinc_files/colformat.txt.
# Column specifications:
# IDCOL 1
# MJDCOL 2
# RACOL 5
# DECCOL 6
# MAGCOL 9
# BANDCOL 8
# OBSCODECOL 16
# Read 2662 lines from observatory code file /home/ellie/research/lsst/heliolinc_files/ObsCodes.html
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a3_-11.0_30days_cmi.csv read successfully to the end.
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a3_-11.0_30days_cmi.csv read successfully to the end.
# Finished reading heliocentric ephemeris file /home/ellie/research/lsst/heliolinc_files/Earth1day2020s_02a.csv for the Earth.
# 18 unique images were identified.
# Given our total of 18 detections,
# we have 1 detections per image, on average
# In main, exposure time was corrected for 18 out of 18 images
# Writing output image catalog /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a3_-11.0.txt with 18 lines
# Inside make_tracklets8
# Configuration parameters for new make_tracklets:
# Min. number of tracklet points: 2
# Time-tolerance for matching detections on the same image: 5.78704e-06 days (0.5 seconds)
# Maximum angular velocity: 1.5 deg/day
# Minimum angular velocity: 0 deg/day
# Minimum angular arc: 0 arcsec
# Maximum inter-image time interval: 0.0625 days (90 minutes)
# Minimum inter-image time interval: 1.15741e-05 days (0.0166667 minutes)
# Image radius: 2 degrees
# Maximum Great Circle Residual for tracklets with more than two points: 0.5 arcsec
# Maximum non-exclusive tracklet length is 2 points
# find_pairs is sanity-checking indvecs
# Sanity-check finished
# make_tracklets is sanity-checking indvecs
# Sanity-check finished
# 3 overlapping images found for image 0; current time is Mon Jan 26 04:37:46 2026
#
# 3 overlapping images found for image 1; current time is Mon Jan 26 04:37:46 2026
#
# 3 overlapping images found for image 2; current time is Mon Jan 26 04:37:46 2026
#
# 3 overlapping images found for image 3; current time is Mon Jan 26 04:37:46 2026
#
# 0 overlapping images found for image 4; current time is Mon Jan 26 04:37:46 2026
#
# 1 overlapping images found for image 5; current time is Mon Jan 26 04:37:46 2026
#
# 1 overlapping images found for image 6; current time is Mon Jan 26 04:37:46 2026
#
# 0 overlapping images found for image 7; current time is Mon Jan 26 04:37:46 2026
#
# 2 overlapping images found for image 8; current time is Mon Jan 26 04:37:46 2026
#
# 2 overlapping images found for image 9; current time is Mon Jan 26 04:37:46 2026
#
# 2 overlapping images found for image 10; current time is Mon Jan 26 04:37:46 2026
#
# 0 overlapping images found for image 11; current time is Mon Jan 26 04:37:46 2026
#
# 3 overlapping images found for image 12; current time is Mon Jan 26 04:37:46 2026
#
# 3 overlapping images found for image 13; current time is Mon Jan 26 04:37:46 2026
#
# 3 overlapping images found for image 14; current time is Mon Jan 26 04:37:46 2026
#
# 3 overlapping images found for image 15; current time is Mon Jan 26 04:37:46 2026
#
# 1 overlapping images found for image 16; current time is Mon Jan 26 04:37:46 2026
#
# 1 overlapping images found for image 17; current time is Mon Jan 26 04:37:46 2026
#
# merge_pairs is sanity-checking indvecs
# Sanity-check finished
# merge_pairs3 finished OK
# Output image catalog /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a3_-11.0.txt, with 18 lines, has been written
# Writing paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a3_-11.0.csv with 15 lines
# Writing tracklet file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/tracklets_pratchett_ng_a3_-11.0.csv with 5 lines
# Writing trk2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/trk2det_pratchett_ng_a3_-11.0.csv with 15 lines
# Checking out argv[1] = -dets.
# Checking out argv[3] = -earth.
# Checking out argv[5] = -obscode.
# Checking out argv[7] = -colformat.
# Checking out argv[9] = -outimgs.
# Checking out argv[11] = -pairdets.
# Checking out argv[13] = -tracklets.
# Checking out argv[15] = -trk2det.
#
# Input detection file is called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a1_-10.0_30days_cmi.csv
#
# No input image file specified: image catalog will be generated internally.
# column formatting file = /home/ellie/research/lsst/heliolinc_files/colformat.txt
# Observatory code file /home/ellie/research/lsst/heliolinc_files/ObsCodes.html
# Output image file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a1_-10.0.txt
# Output paired detection file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a1_-10.0.csv
# Output tracklet file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/tracklets_pratchett_ng_a1_-10.0.csv
# Output tracklet-to-detection mapping file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/trk2det_pratchett_ng_a1_-10.0.csv
# Heliocentric ephemeris file for the Earth: /home/ellie/research/lsst/heliolinc_files/Earth1day2020s_02a.csv
# Defaulting to image radius = 2 degrees.
# Using simpler, less memory-efficient algorithm: matchrad and trkfrac parameters have no effect
# Defaulting to max time interval = 1.5 hours.
# Defaulting to min time interval = 0.000277778 hours.
# Defaulting to min angular velocity = 0 deg/day.
# Defaulting to maximum angular velocity = 1.5 deg/day.
# Defaulting to minimum number of points per tracklet = 2
# Defaulting to maximum number of points for a non-exclusive tracklet = 2
# Defaulting to time offset (added to obs times to get UTC) = 0 seconds
# Defaulting to minimum tracklet length = 0 arcsec.
# Defulting to maximum tracklet Great Circle residual = 0.5 arcsec.
# WARNING: only 7 column specifications, of 14 expected, were read from column format file /home/ellie/research/lsst/heliolinc_files/colformat.txt.
# Column specifications:
# IDCOL 1
# MJDCOL 2
# RACOL 5
# DECCOL 6
# MAGCOL 9
# BANDCOL 8
# OBSCODECOL 16
# Read 2662 lines from observatory code file /home/ellie/research/lsst/heliolinc_files/ObsCodes.html
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a1_-10.0_30days_cmi.csv read successfully to the end.
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a1_-10.0_30days_cmi.csv read successfully to the end.
# Finished reading heliocentric ephemeris file /home/ellie/research/lsst/heliolinc_files/Earth1day2020s_02a.csv for the Earth.
# 18 unique images were identified.
# Given our total of 18 detections,
# we have 1 detections per image, on average
# In main, exposure time was corrected for 18 out of 18 images
# Writing output image catalog /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a1_-10.0.txt with 18 lines
# Inside make_tracklets8
# Configuration parameters for new make_tracklets:
# Min. number of tracklet points: 2
# Time-tolerance for matching detections on the same image: 5.78704e-06 days (0.5 seconds)
# Maximum angular velocity: 1.5 deg/day
# Minimum angular velocity: 0 deg/day
# Minimum angular arc: 0 arcsec
# Maximum inter-image time interval: 0.0625 days (90 minutes)
# Minimum inter-image time interval: 1.15741e-05 days (0.0166667 minutes)
# Image radius: 2 degrees
# Maximum Great Circle Residual for tracklets with more than two points: 0.5 arcsec
# Maximum non-exclusive tracklet length is 2 points
# find_pairs is sanity-checking indvecs
# Sanity-check finished
# make_tracklets is sanity-checking indvecs
# Sanity-check finished
# 3 overlapping images found for image 0; current time is Mon Jan 26 04:37:46 2026
#
# 3 overlapping images found for image 1; current time is Mon Jan 26 04:37:46 2026
#
# 3 overlapping images found for image 2; current time is Mon Jan 26 04:37:46 2026
#
# 3 overlapping images found for image 3; current time is Mon Jan 26 04:37:46 2026
#
# 0 overlapping images found for image 4; current time is Mon Jan 26 04:37:46 2026
#
# 1 overlapping images found for image 5; current time is Mon Jan 26 04:37:46 2026
#
# 1 overlapping images found for image 6; current time is Mon Jan 26 04:37:46 2026
#
# 0 overlapping images found for image 7; current time is Mon Jan 26 04:37:46 2026
#
# 2 overlapping images found for image 8; current time is Mon Jan 26 04:37:46 2026
#
# 2 overlapping images found for image 9; current time is Mon Jan 26 04:37:46 2026
#
# 2 overlapping images found for image 10; current time is Mon Jan 26 04:37:46 2026
#
# 0 overlapping images found for image 11; current time is Mon Jan 26 04:37:46 2026
#
# 3 overlapping images found for image 12; current time is Mon Jan 26 04:37:46 2026
#
# 3 overlapping images found for image 13; current time is Mon Jan 26 04:37:46 2026
#
# 3 overlapping images found for image 14; current time is Mon Jan 26 04:37:46 2026
#
# 3 overlapping images found for image 15; current time is Mon Jan 26 04:37:46 2026
#
# 1 overlapping images found for image 16; current time is Mon Jan 26 04:37:46 2026
#
# 1 overlapping images found for image 17; current time is Mon Jan 26 04:37:46 2026
#
# merge_pairs is sanity-checking indvecs
# Sanity-check finished
# merge_pairs3 finished OK
# Output image catalog /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a1_-10.0.txt, with 18 lines, has been written
# Writing paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a1_-10.0.csv with 15 lines
# Writing tracklet file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/tracklets_pratchett_ng_a1_-10.0.csv with 5 lines
# Writing trk2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/trk2det_pratchett_ng_a1_-10.0.csv with 15 lines
# Checking out argv[1] = -dets.
# Checking out argv[3] = -earth.
# Checking out argv[5] = -obscode.
# Checking out argv[7] = -colformat.
# Checking out argv[9] = -outimgs.
# Checking out argv[11] = -pairdets.
# Checking out argv[13] = -tracklets.
# Checking out argv[15] = -trk2det.
#
# Input detection file is called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a2_-10.0_30days_cmi.csv
#
# No input image file specified: image catalog will be generated internally.
# column formatting file = /home/ellie/research/lsst/heliolinc_files/colformat.txt
# Observatory code file /home/ellie/research/lsst/heliolinc_files/ObsCodes.html
# Output image file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a2_-10.0.txt
# Output paired detection file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a2_-10.0.csv
# Output tracklet file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/tracklets_pratchett_ng_a2_-10.0.csv
# Output tracklet-to-detection mapping file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/trk2det_pratchett_ng_a2_-10.0.csv
# Heliocentric ephemeris file for the Earth: /home/ellie/research/lsst/heliolinc_files/Earth1day2020s_02a.csv
# Defaulting to image radius = 2 degrees.
# Using simpler, less memory-efficient algorithm: matchrad and trkfrac parameters have no effect
# Defaulting to max time interval = 1.5 hours.
# Defaulting to min time interval = 0.000277778 hours.
# Defaulting to min angular velocity = 0 deg/day.
# Defaulting to maximum angular velocity = 1.5 deg/day.
# ...
#
# Input detection file is called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a2_2.0_30days_cmi.csv
#
# No input image file specified: image catalog will be generated internally.
# column formatting file = /home/ellie/research/lsst/heliolinc_files/colformat.txt
# Observatory code file /home/ellie/research/lsst/heliolinc_files/ObsCodes.html
# Output image file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a2_2.0.txt
# Output paired detection file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a2_2.0.csv
# Output tracklet file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/tracklets_pratchett_ng_a2_2.0.csv
# Output tracklet-to-detection mapping file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/trk2det_pratchett_ng_a2_2.0.csv
# Heliocentric ephemeris file for the Earth: /home/ellie/research/lsst/heliolinc_files/Earth1day2020s_02a.csv
# Defaulting to image radius = 2 degrees.
# Using simpler, less memory-efficient algorithm: matchrad and trkfrac parameters have no effect
# Defaulting to max time interval = 1.5 hours.
# Defaulting to min time interval = 0.000277778 hours.
# Defaulting to min angular velocity = 0 deg/day.
# Defaulting to maximum angular velocity = 1.5 deg/day.
# Defaulting to minimum number of points per tracklet = 2
# Defaulting to maximum number of points for a non-exclusive tracklet = 2
# Defaulting to time offset (added to obs times to get UTC) = 0 seconds
# Defaulting to minimum tracklet length = 0 arcsec.
# Defulting to maximum tracklet Great Circle residual = 0.5 arcsec.
# WARNING: only 7 column specifications, of 14 expected, were read from column format file /home/ellie/research/lsst/heliolinc_files/colformat.txt.
# Column specifications:
# IDCOL 1
# MJDCOL 2
# RACOL 5
# DECCOL 6
# MAGCOL 9
# BANDCOL 8
# OBSCODECOL 16
# Read 2662 lines from observatory code file /home/ellie/research/lsst/heliolinc_files/ObsCodes.html
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a2_2.0_30days_cmi.csv read successfully to the end.
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a2_2.0_30days_cmi.csv read successfully to the end.
# Finished reading heliocentric ephemeris file /home/ellie/research/lsst/heliolinc_files/Earth1day2020s_02a.csv for the Earth.
# 12 unique images were identified.
# Given our total of 12 detections,
# we have 1 detections per image, on average
# In main, exposure time was corrected for 12 out of 12 images
# Writing output image catalog /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a2_2.0.txt with 12 lines
# Inside make_tracklets8
# Configuration parameters for new make_tracklets:
# Min. number of tracklet points: 2
# Time-tolerance for matching detections on the same image: 5.78704e-06 days (0.5 seconds)
# Maximum angular velocity: 1.5 deg/day
# Minimum angular velocity: 0 deg/day
# Minimum angular arc: 0 arcsec
# Maximum inter-image time interval: 0.0625 days (90 minutes)
# Minimum inter-image time interval: 1.15741e-05 days (0.0166667 minutes)
# Image radius: 2 degrees
# Maximum Great Circle Residual for tracklets with more than two points: 0.5 arcsec
# Maximum non-exclusive tracklet length is 2 points
# find_pairs is sanity-checking indvecs
# Sanity-check finished
# make_tracklets is sanity-checking indvecs
# Sanity-check finished
# 3 overlapping images found for image 0; current time is Mon Jan 26 04:37:48 2026
#
# 3 overlapping images found for image 1; current time is Mon Jan 26 04:37:48 2026
#
# 3 overlapping images found for image 2; current time is Mon Jan 26 04:37:48 2026
#
# 3 overlapping images found for image 3; current time is Mon Jan 26 04:37:48 2026
#
# 1 overlapping images found for image 4; current time is Mon Jan 26 04:37:48 2026
#
# 1 overlapping images found for image 5; current time is Mon Jan 26 04:37:48 2026
#
# 1 overlapping images found for image 6; current time is Mon Jan 26 04:37:48 2026
#
# 1 overlapping images found for image 7; current time is Mon Jan 26 04:37:48 2026
#
# 2 overlapping images found for image 8; current time is Mon Jan 26 04:37:48 2026
#
# 2 overlapping images found for image 9; current time is Mon Jan 26 04:37:48 2026
#
# 2 overlapping images found for image 10; current time is Mon Jan 26 04:37:48 2026
#
# 0 overlapping images found for image 11; current time is Mon Jan 26 04:37:48 2026
#
# merge_pairs is sanity-checking indvecs
# Sanity-check finished
# merge_pairs3 finished OK
# Output image catalog /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a2_2.0.txt, with 12 lines, has been written
# Writing paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a2_2.0.csv with 3 lines
# Writing tracklet file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/tracklets_pratchett_ng_a2_2.0.csv with 1 lines
# Writing trk2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/trk2det_pratchett_ng_a2_2.0.csv with 3 lines
# Checking out argv[1] = -dets.
# Checking out argv[3] = -earth.
# Checking out argv[5] = -obscode.
# Checking out argv[7] = -colformat.
# Checking out argv[9] = -outimgs.
# Checking out argv[11] = -pairdets.
# Checking out argv[13] = -tracklets.
# Checking out argv[15] = -trk2det.
#
# Input detection file is called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a3_2.0_30days_cmi.csv
#
# No input image file specified: image catalog will be generated internally.
# column formatting file = /home/ellie/research/lsst/heliolinc_files/colformat.txt
# Observatory code file /home/ellie/research/lsst/heliolinc_files/ObsCodes.html
# Output image file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a3_2.0.txt
# Output paired detection file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a3_2.0.csv
# Output tracklet file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/tracklets_pratchett_ng_a3_2.0.csv
# Output tracklet-to-detection mapping file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/trk2det_pratchett_ng_a3_2.0.csv
# Heliocentric ephemeris file for the Earth: /home/ellie/research/lsst/heliolinc_files/Earth1day2020s_02a.csv
# Defaulting to image radius = 2 degrees.
# Using simpler, less memory-efficient algorithm: matchrad and trkfrac parameters have no effect
# Defaulting to max time interval = 1.5 hours.
# Defaulting to min time interval = 0.000277778 hours.
# Defaulting to min angular velocity = 0 deg/day.
# Defaulting to maximum angular velocity = 1.5 deg/day.
# Defaulting to minimum number of points per tracklet = 2
# Defaulting to maximum number of points for a non-exclusive tracklet = 2
# Defaulting to time offset (added to obs times to get UTC) = 0 seconds
# Defaulting to minimum tracklet length = 0 arcsec.
# Defulting to maximum tracklet Great Circle residual = 0.5 arcsec.
# WARNING: only 7 column specifications, of 14 expected, were read from column format file /home/ellie/research/lsst/heliolinc_files/colformat.txt.
# Column specifications:
# IDCOL 1
# MJDCOL 2
# RACOL 5
# DECCOL 6
# MAGCOL 9
# BANDCOL 8
# OBSCODECOL 16
# Read 2662 lines from observatory code file /home/ellie/research/lsst/heliolinc_files/ObsCodes.html
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a3_2.0_30days_cmi.csv read successfully to the end.
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a3_2.0_30days_cmi.csv read successfully to the end.
# Finished reading heliocentric ephemeris file /home/ellie/research/lsst/heliolinc_files/Earth1day2020s_02a.csv for the Earth.
# 15 unique images were identified.
# Given our total of 15 detections,
# we have 1 detections per image, on average
# In main, exposure time was corrected for 15 out of 15 images
# Writing output image catalog /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a3_2.0.txt with 15 lines
# Inside make_tracklets8
# Configuration parameters for new make_tracklets:
# Min. number of tracklet points: 2
# Time-tolerance for matching detections on the same image: 5.78704e-06 days (0.5 seconds)
# Maximum angular velocity: 1.5 deg/day
# Minimum angular velocity: 0 deg/day
# Minimum angular arc: 0 arcsec
# Maximum inter-image time interval: 0.0625 days (90 minutes)
# Minimum inter-image time interval: 1.15741e-05 days (0.0166667 minutes)
# Image radius: 2 degrees
# Maximum Great Circle Residual for tracklets with more than two points: 0.5 arcsec
# Maximum non-exclusive tracklet length is 2 points
# find_pairs is sanity-checking indvecs
# Sanity-check finished
# make_tracklets is sanity-checking indvecs
# Sanity-check finished
# 1 overlapping images found for image 0; current time is Mon Jan 26 04:37:48 2026
#
# 1 overlapping images found for image 1; current time is Mon Jan 26 04:37:48 2026
#
# 3 overlapping images found for image 2; current time is Mon Jan 26 04:37:48 2026
#
# 3 overlapping images found for image 3; current time is Mon Jan 26 04:37:48 2026
#
# 3 overlapping images found for image 4; current time is Mon Jan 26 04:37:48 2026
#
# 3 overlapping images found for image 5; current time is Mon Jan 26 04:37:48 2026
#
# 1 overlapping images found for image 6; current time is Mon Jan 26 04:37:48 2026
#
# 1 overlapping images found for image 7; current time is Mon Jan 26 04:37:48 2026
#
# 1 overlapping images found for image 8; current time is Mon Jan 26 04:37:48 2026
#
# 1 overlapping images found for image 9; current time is Mon Jan 26 04:37:48 2026
#
# 1 overlapping images found for image 10; current time is Mon Jan 26 04:37:48 2026
#
# 1 overlapping images found for image 11; current time is Mon Jan 26 04:37:48 2026
#
# 0 overlapping images found for image 12; current time is Mon Jan 26 04:37:48 2026
#
# 1 overlapping images found for image 13; current time is Mon Jan 26 04:37:48 2026
#
# 1 overlapping images found for image 14; current time is Mon Jan 26 04:37:48 2026
#
# merge_pairs is sanity-checking indvecs
# Sanity-check finished
# merge_pairs3 finished OK
# Output image catalog /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a3_2.0.txt, with 15 lines, has been written
# Writing paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a3_2.0.csv with 14 lines
# Writing tracklet file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/tracklets_pratchett_ng_a3_2.0.csv with 6 lines
# Writing trk2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/trk2det_pratchett_ng_a3_2.0.csv with 14 lines
# Checking out argv[1] = -dets.
# Checking out argv[3] = -earth.
# Checking out argv[5] = -obscode.
# Checking out argv[7] = -colformat.
# Checking out argv[9] = -outimgs.
# Checking out argv[11] = -pairdets.
# Checking out argv[13] = -tracklets.
# Checking out argv[15] = -trk2det.
#
# Input detection file is called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a3_3.0_30days_cmi.csv
#
# No input image file specified: image catalog will be generated internally.
# column formatting file = /home/ellie/research/lsst/heliolinc_files/colformat.txt
# Observatory code file /home/ellie/research/lsst/heliolinc_files/ObsCodes.html
# Output image file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a3_3.0.txt
# Output paired detection file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a3_3.0.csv
# Output tracklet file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/tracklets_pratchett_ng_a3_3.0.csv
# Output tracklet-to-detection mapping file will be called /home/ellie/research/lsst/sorcha_output/127005pratchett_new/trk2det_pratchett_ng_a3_3.0.csv
# Heliocentric ephemeris file for the Earth: /home/ellie/research/lsst/heliolinc_files/Earth1day2020s_02a.csv
# Defaulting to image radius = 2 degrees.
# Using simpler, less memory-efficient algorithm: matchrad and trkfrac parameters have no effect
# Defaulting to max time interval = 1.5 hours.
# Defaulting to min time interval = 0.000277778 hours.
# Defaulting to min angular velocity = 0 deg/day.
# Defaulting to maximum angular velocity = 1.5 deg/day.
# Defaulting to minimum number of points per tracklet = 2
# Defaulting to maximum number of points for a non-exclusive tracklet = 2
# Defaulting to time offset (added to obs times to get UTC) = 0 seconds
# Defaulting to minimum tracklet length = 0 arcsec.
# Defulting to maximum tracklet Great Circle residual = 0.5 arcsec.
# WARNING: only 7 column specifications, of 14 expected, were read from column format file /home/ellie/research/lsst/heliolinc_files/colformat.txt.
# Column specifications:
# IDCOL 1
# MJDCOL 2
# RACOL 5
# DECCOL 6
# MAGCOL 9
# BANDCOL 8
# OBSCODECOL 16
# Read 2662 lines from observatory code file /home/ellie/research/lsst/heliolinc_files/ObsCodes.html
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a3_3.0_30days_cmi.csv read successfully to the end.
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a3_3.0_30days_cmi.csv read successfully to the end.
# Finished reading heliocentric ephemeris file /home/ellie/research/lsst/heliolinc_files/Earth1day2020s_02a.csv for the Earth.
# 14 unique images were identified.
# Given our total of 14 detections,
# we have 1 detections per image, on average
# In main, exposure time was corrected for 14 out of 14 images
# Writing output image catalog /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a3_3.0.txt with 14 lines
# Inside make_tracklets8
# Configuration parameters for new make_tracklets:
# Min. number of tracklet points: 2
# Time-tolerance for matching detections on the same image: 5.78704e-06 days (0.5 seconds)
# Maximum angular velocity: 1.5 deg/day
# Minimum angular velocity: 0 deg/day
# Minimum angular arc: 0 arcsec
# Maximum inter-image time interval: 0.0625 days (90 minutes)
# Minimum inter-image time interval: 1.15741e-05 days (0.0166667 minutes)
# Image radius: 2 degrees
# Maximum Great Circle Residual for tracklets with more than two points: 0.5 arcsec
# Maximum non-exclusive tracklet length is 2 points
# find_pairs is sanity-checking indvecs
# Sanity-check finished
# make_tracklets is sanity-checking indvecs
# Sanity-check finished
# 1 overlapping images found for image 0; current time is Mon Jan 26 04:37:48 2026
#
# 1 overlapping images found for image 1; current time is Mon Jan 26 04:37:48 2026
#
# 1 overlapping images found for image 2; current time is Mon Jan 26 04:37:48 2026
#
# 1 overlapping images found for image 3; current time is Mon Jan 26 04:37:48 2026
#
# 1 overlapping images found for image 4; current time is Mon Jan 26 04:37:48 2026
#
# 1 overlapping images found for image 5; current time is Mon Jan 26 04:37:48 2026
#
# 4 overlapping images found for image 6; current time is Mon Jan 26 04:37:48 2026
#
# 4 overlapping images found for image 7; current time is Mon Jan 26 04:37:48 2026
#
# 5 overlapping images found for image 8; current time is Mon Jan 26 04:37:48 2026
#
# 5 overlapping images found for image 9; current time is Mon Jan 26 04:37:48 2026
#
# 5 overlapping images found for image 10; current time is Mon Jan 26 04:37:48 2026
#
# 3 overlapping images found for image 11; current time is Mon Jan 26 04:37:48 2026
#
# 0 overlapping images found for image 12; current time is Mon Jan 26 04:37:48 2026
#
# 0 overlapping images found for image 13; current time is Mon Jan 26 04:37:48 2026
#
# merge_pairs is sanity-checking indvecs
# Sanity-check finished
# merge_pairs3 finished OK
# Output image catalog /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a3_3.0.txt, with 14 lines, has been written
# Writing paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a3_3.0.csv with 12 lines
# Writing tracklet file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/tracklets_pratchett_ng_a3_3.0.csv with 15 lines
# Writing trk2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/trk2det_pratchett_ng_a3_3.0.csv with 30 lines

# %%
## run heliolinx

for l in range(len(ofnames)):

    subprocess.run(['heliolinc', '-imgs', '{0}outim_{1}.txt'.format(sfpath, ofnames[l]), \
                    '-pairdets', '{0}pairdets_{1}.csv'.format(sfpath, ofnames[l]), \
                    '-tracklets', '{0}tracklets_{1}.csv'.format(sfpath, ofnames[l]), \
                    '-trk2det', '{0}trk2det_{1}.csv'.format(sfpath, ofnames[l]), \
                    '-obspos', earth1day_path, '-heliodist', hypo_path, '-outsum',\
                    '{0}sum_{1}.csv'.format(sfpath, ofnames[l]), '-clust2det', \
                    '{0}clust2det_{1}.csv'.format(sfpath, ofnames[l])])
# Out:
# Checking out argv[1] = -imgs.
# Checking out argv[3] = -pairdets.
# Checking out argv[5] = -tracklets.
# Checking out argv[7] = -trk2det.
# Checking out argv[9] = -obspos.
# Checking out argv[11] = -heliodist.
# Checking out argv[13] = -outsum.
# Checking out argv[15] = -clust2det.
# input image file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_cart.txt
# input detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_cart.csv
# input tracklet file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/tracklets_pratchett_cart.csv
# input trk2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/trk2det_pratchett_cart.csv
# input observer position file /home/ellie/research/lsst/heliolinc_files/Earth1day2020s_02a.csv
# input heliocentric hypothesis file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/hihyp00b_mb.txt
# input reference MJD 0
# Defaulting to cluster radius = 100000km
# Defaulting to min. geocentric distance for cluster scaling = 0.5AU
# Minimum cluster radius, which will apply for all geocentric distances less
# than 0.5AU, is 50000km
# Defaulting to DBSCAN npt (min. no. of tracklets in a linkage) = 3
# Defaulting to minimum number of unique nights = 3
# Defaulting to minimum time span for a linkage = 1 days
# Defaulting to minimum geocentric distance = 0.10000000000000001 AU
# Defaulting to maximum geocentric distance = 100 AU
# Defaulting to logarithmic step size for geocentric distance bins = 1.5
# Defaulting to minimum geocentric distance at observation = 0 AU
# Defaulting to minimum impact parameter = 0 km
# For Keplerian integration, defaulting to f and g functions
# rather than universal variables
# Defaulting to maximum v_inf relative to the sun = 0 km/sec
# summary output file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/sum_pratchett_cart.csv
# output clust2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/clust2det_pratchett_cart.csv
# Heliocentric ephemeris for Earth is named /home/ellie/research/lsst/heliolinc_files/Earth1day2020s_02a.csv
# File with heliocentric motion hypothesis is named /home/ellie/research/lsst/sorcha_output/127005pratchett_new/hihyp00b_mb.txt
# Read 15 data lines from paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_cart.csv
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_cart.txt read successfully to the end.
# Read 18 data lines from image file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_cart.txt
# Read 5 data lines from tracklet file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/tracklets_pratchett_cart.csv
# Read 15 data lines from trk2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/trk2det_pratchett_cart.csv
# Configuration parameters:
# MJD of reference time: 0
# DBSCAN clustering radius: 100000 km
# DBSCAN npt: 3
# Min number of distinct observing nights for a valid linkage: 3
# Min time span for a valid linkage: 1 days
# Min geocentric distance (center of innermost bin): 0.10000000000000001 AU
# Max geocentric distance (will be exceeded by center only of the outermost bin): 100 AU
# Logarthmic step size (and bin width) for geocentric distance bins: 1.5
# Minimum inferred geocentric distance for a valid tracklet: 0 AU
# Minimum inferred impact parameter (w.r.t. Earth) for a valid tracklet: 0 km
#
# User did not input a positive-valued reference MJD in the
# acceptable range, so heliolinc will generate one internally
# MJD range is 60355.354434300003 to 60383.3567931
# Suggested reference value is 60369.36
# Adopting reference MJD = 60369.36
# Working on hypothesis 0: 1.50 AU, -32.10 km/sec 0.87 GMsun/r^2
# 5 input pairs/tracklets led to 5 physically reasonable state vectors
# Geocentric distance step 1, bin-center distance is 0.10 AU
# Geocentric distance step 2, bin-center distance is 0.15 AU
# Geocentric distance step 3, bin-center distance is 0.23 AU
# Geocentric distance step 4, bin-center distance is 0.34 AU
# Geocentric distance step 5, bin-center distance is 0.51 AU
# KDRclust_6i01 finished clustering geobin 5, with 0 = 0 clusters found
# Final analysis of geobin 5 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 6, bin-center distance is 0.76 AU
# KDRclust_6i01 finished clustering geobin 6, with 0 = 0 clusters found
# Final analysis of geobin 6 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 7, bin-center distance is 1.14 AU
# Geocentric distance step 8, bin-center distance is 1.71 AU
# Geocentric distance step 9, bin-center distance is 2.56 AU
# Geocentric distance step 10, bin-center distance is 3.84 AU
# Geocentric distance step 11, bin-center distance is 5.77 AU
# Geocentric distance step 12, bin-center distance is 8.65 AU
# Geocentric distance step 13, bin-center distance is 12.97 AU
# Geocentric distance step 14, bin-center distance is 19.46 AU
# Geocentric distance step 15, bin-center distance is 29.19 AU
# Geocentric distance step 16, bin-center distance is 43.79 AU
# Geocentric distance step 17, bin-center distance is 65.68 AU
# Geocentric distance step 18, bin-center distance is 98.53 AU
# Geocentric distance step 19, bin-center distance is 147.79 AU
# Across all geobins, identified 0 total linkages
# This hypothesis: 0 deduplicated linkages; total now 0 linkages totalling 0 detections.
# Working on hypothesis 1: 1.50 AU, -27.51 km/sec 0.64 GMsun/r^2
# 5 input pairs/tracklets led to 5 physically reasonable state vectors
# Geocentric distance step 1, bin-center distance is 0.10 AU
# Geocentric distance step 2, bin-center distance is 0.15 AU
# Geocentric distance step 3, bin-center distance is 0.23 AU
# Geocentric distance step 4, bin-center distance is 0.34 AU
# Geocentric distance step 5, bin-center distance is 0.51 AU
# KDRclust_6i01 finished clustering geobin 5, with 0 = 0 clusters found
# Final analysis of geobin 5 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 6, bin-center distance is 0.76 AU
# KDRclust_6i01 finished clustering geobin 6, with 0 = 0 clusters found
# Final analysis of geobin 6 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 7, bin-center distance is 1.14 AU
# Geocentric distance step 8, bin-center distance is 1.71 AU
# Geocentric distance step 9, bin-center distance is 2.56 AU
# Geocentric distance step 10, bin-center distance is 3.84 AU
# Geocentric distance step 11, bin-center distance is 5.77 AU
# Geocentric distance step 12, bin-center distance is 8.65 AU
# Geocentric distance step 13, bin-center distance is 12.97 AU
# Geocentric distance step 14, bin-center distance is 19.46 AU
# Geocentric distance step 15, bin-center distance is 29.19 AU
# Geocentric distance step 16, bin-center distance is 43.79 AU
# Geocentric distance step 17, bin-center distance is 65.68 AU
# Geocentric distance step 18, bin-center distance is 98.53 AU
# Geocentric distance step 19, bin-center distance is 147.79 AU
# Across all geobins, identified 0 total linkages
# This hypothesis: 0 deduplicated linkages; total now 0 linkages totalling 0 detections.
# Working on hypothesis 2: 1.50 AU, -22.93 km/sec 0.44 GMsun/r^2
# 5 input pairs/tracklets led to 5 physically reasonable state vectors
# Geocentric distance step 1, bin-center distance is 0.10 AU
# Geocentric distance step 2, bin-center distance is 0.15 AU
# Geocentric distance step 3, bin-center distance is 0.23 AU
# Geocentric distance step 4, bin-center distance is 0.34 AU
# Geocentric distance step 5, bin-center distance is 0.51 AU
# KDRclust_6i01 finished clustering geobin 5, with 0 = 0 clusters found
# Final analysis of geobin 5 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 6, bin-center distance is 0.76 AU
# KDRclust_6i01 finished clustering geobin 6, with 0 = 0 clusters found
# Final analysis of geobin 6 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 7, bin-center distance is 1.14 AU
# Geocentric distance step 8, bin-center distance is 1.71 AU
# Geocentric distance step 9, bin-center distance is 2.56 AU
# Geocentric distance step 10, bin-center distance is 3.84 AU
# Geocentric distance step 11, bin-center distance is 5.77 AU
# Geocentric distance step 12, bin-center distance is 8.65 AU
# Geocentric distance step 13, bin-center distance is 12.97 AU
# Geocentric distance step 14, bin-center distance is 19.46 AU
# Geocentric distance step 15, bin-center distance is 29.19 AU
# Geocentric distance step 16, bin-center distance is 43.79 AU
# Geocentric distance step 17, bin-center distance is 65.68 AU
# Geocentric distance step 18, bin-center distance is 98.53 AU
# Geocentric distance step 19, bin-center distance is 147.79 AU
# Across all geobins, identified 0 total linkages
# This hypothesis: 0 deduplicated linkages; total now 0 linkages totalling 0 detections.
# Working on hypothesis 3: 1.50 AU, -18.34 km/sec 0.28 GMsun/r^2
# 5 input pairs/tracklets led to 5 physically reasonable state vectors
# Geocentric distance step 1, bin-center distance is 0.10 AU
# Geocentric distance step 2, bin-center distance is 0.15 AU
# Geocentric distance step 3, bin-center distance is 0.23 AU
# Geocentric distance step 4, bin-center distance is 0.34 AU
# Geocentric distance step 5, bin-center distance is 0.51 AU
# KDRclust_6i01 finished clustering geobin 5, with 0 = 0 clusters found
# Final analysis of geobin 5 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 6, bin-center distance is 0.76 AU
# KDRclust_6i01 finished clustering geobin 6, with 0 = 0 clusters found
# Final analysis of geobin 6 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 7, bin-center distance is 1.14 AU
# Geocentric distance step 8, bin-center distance is 1.71 AU
# Geocentric distance step 9, bin-center distance is 2.56 AU
# Geocentric distance step 10, bin-center distance is 3.84 AU
# Geocentric distance step 11, bin-center distance is 5.77 AU
# Geocentric distance step 12, bin-center distance is 8.65 AU
# Geocentric distance step 13, bin-center distance is 12.97 AU
# Geocentric distance step 14, bin-center distance is 19.46 AU
# Geocentric distance step 15, bin-center distance is 29.19 AU
# Geocentric distance step 16, bin-center distance is 43.79 AU
# Geocentric distance step 17, bin-center distance is 65.68 AU
# Geocentric distance step 18, bin-center distance is 98.53 AU
# Geocentric distance step 19, bin-center distance is 147.79 AU
# Across all geobins, identified 0 total linkages
# This hypothesis: 0 deduplicated linkages; total now 0 linkages totalling 0 detections.
# Working on hypothesis 4: 1.50 AU, -13.76 km/sec 0.16 GMsun/r^2
# 5 input pairs/tracklets led to 5 physically reasonable state vectors
# Geocentric distance step 1, bin-center distance is 0.10 AU
# Geocentric distance step 2, bin-center distance is 0.15 AU
# Geocentric distance step 3, bin-center distance is 0.23 AU
# Geocentric distance step 4, bin-center distance is 0.34 AU
# Geocentric distance step 5, bin-center distance is 0.51 AU
# KDRclust_6i01 finished clustering geobin 5, with 0 = 0 clusters found
# Final analysis of geobin 5 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 6, bin-center distance is 0.76 AU
# KDRclust_6i01 finished clustering geobin 6, with 0 = 0 clusters found
# Final analysis of geobin 6 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 7, bin-center distance is 1.14 AU
# Geocentric distance step 8, bin-center distance is 1.71 AU
# Geocentric distance step 9, bin-center distance is 2.56 AU
# Geocentric distance step 10, bin-center distance is 3.84 AU
# Geocentric distance step 11, bin-center distance is 5.77 AU
# Geocentric distance step 12, bin-center distance is 8.65 AU
# Geocentric distance step 13, bin-center distance is 12.97 AU
# Geocentric distance step 14, bin-center distance is 19.46 AU
# Geocentric distance step 15, bin-center distance is 29.19 AU
# Geocentric distance step 16, bin-center distance is 43.79 AU
# Geocentric distance step 17, bin-center distance is 65.68 AU
# Geocentric distance step 18, bin-center distance is 98.53 AU
# Geocentric distance step 19, bin-center distance is 147.79 AU
# Across all geobins, identified 0 total linkages
# This hypothesis: 0 deduplicated linkages; total now 0 linkages totalling 0 detections.
# Working on hypothesis 5: 1.50 AU, -9.17 km/sec 0.07 GMsun/r^2
# 5 input pairs/tracklets led to 5 physically reasonable state vectors
# Geocentric distance step 1, bin-center distance is 0.10 AU
# Geocentric distance step 2, bin-center distance is 0.15 AU
# Geocentric distance step 3, bin-center distance is 0.23 AU
# Geocentric distance step 4, bin-center distance is 0.34 AU
# Geocentric distance step 5, bin-center distance is 0.51 AU
# KDRclust_6i01 finished clustering geobin 5, with 0 = 0 clusters found
# Final analysis of geobin 5 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 6, bin-center distance is 0.76 AU
# KDRclust_6i01 finished clustering geobin 6, with 0 = 0 clusters found
# Final analysis of geobin 6 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 7, bin-center distance is 1.14 AU
# Geocentric distance step 8, bin-center distance is 1.71 AU
# Geocentric distance step 9, bin-center distance is 2.56 AU
# Geocentric distance step 10, bin-center distance is 3.84 AU
# Geocentric distance step 11, bin-center distance is 5.77 AU
# Geocentric distance step 12, bin-center distance is 8.65 AU
# Geocentric distance step 13, bin-center distance is 12.97 AU
# Geocentric distance step 14, bin-center distance is 19.46 AU
# Geocentric distance step 15, bin-center distance is 29.19 AU
# Geocentric distance step 16, bin-center distance is 43.79 AU
# Geocentric distance step 17, bin-center distance is 65.68 AU
# Geocentric distance step 18, bin-center distance is 98.53 AU
# Geocentric distance step 19, bin-center distance is 147.79 AU
# Across all geobins, identified 0 total linkages
# This hypothesis: 0 deduplicated linkages; total now 0 linkages totalling 0 detections.
# Working on hypothesis 6: 1.50 AU, -4.59 km/sec 0.02 GMsun/r^2
# 5 input pairs/tracklets led to 5 physically reasonable state vectors
# Geocentric distance step 1, bin-center distance is 0.10 AU
# Geocentric distance step 2, bin-center distance is 0.15 AU
# Geocentric distance step 3, bin-center distance is 0.23 AU
# Geocentric distance step 4, bin-center distance is 0.34 AU
# Geocentric distance step 5, bin-center distance is 0.51 AU
# KDRclust_6i01 finished clustering geobin 5, with 0 = 0 clusters found
# Final analysis of geobin 5 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 6, bin-center distance is 0.76 AU
# KDRclust_6i01 finished clustering geobin 6, with 0 = 0 clusters found
# Final analysis of geobin 6 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 7, bin-center distance is 1.14 AU
# Geocentric distance step 8, bin-center distance is 1.71 AU
# Geocentric distance step 9, bin-center distance is 2.56 AU
# Geocentric distance step 10, bin-center distance is 3.84 AU
# Geocentric distance step 11, bin-center distance is 5.77 AU
# Geocentric distance step 12, bin-center distance is 8.65 AU
# Geocentric distance step 13, bin-center distance is 12.97 AU
# Geocentric distance step 14, bin-center distance is 19.46 AU
# Geocentric distance step 15, bin-center distance is 29.19 AU
# Geocentric distance step 16, bin-center distance is 43.79 AU
# Geocentric distance step 17, bin-center distance is 65.68 AU
# Geocentric distance step 18, bin-center distance is 98.53 AU
# Geocentric distance step 19, bin-center distance is 147.79 AU
# Across all geobins, identified 0 total linkages
# This hypothesis: 0 deduplicated linkages; total now 0 linkages totalling 0 detections.
# Working on hypothesis 7: 1.50 AU, 0.00 km/sec 0.00 GMsun/r^2
# 5 input pairs/tracklets led to 5 physically reasonable state vectors
# Geocentric distance step 1, bin-center distance is 0.10 AU
# Geocentric distance step 2, bin-center distance is 0.15 AU
# Geocentric distance step 3, bin-center distance is 0.23 AU
# Geocentric distance step 4, bin-center distance is 0.34 AU
# Geocentric distance step 5, bin-center distance is 0.51 AU
# KDRclust_6i01 finished clustering geobin 5, with 0 = 0 clusters found
# Final analysis of geobin 5 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 6, bin-center distance is 0.76 AU
# KDRclust_6i01 finished clustering geobin 6, with 0 = 0 clusters found
# Final analysis of geobin 6 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 7, bin-center distance is 1.14 AU
# Geocentric distance step 8, bin-center distance is 1.71 AU
# Geocentric distance step 9, bin-center distance is 2.56 AU
# Geocentric distance step 10, bin-center distance is 3.84 AU
# Geocentric distance step 11, bin-center distance is 5.77 AU
# Geocentric distance step 12, bin-center distance is 8.65 AU
# Geocentric distance step 13, bin-center distance is 12.97 AU
# Geocentric distance step 14, bin-center distance is 19.46 AU
# Geocentric distance step 15, bin-center distance is 29.19 AU
# Geocentric distance step 16, bin-center distance is 43.79 AU
# Geocentric distance step 17, bin-center distance is 65.68 AU
# Geocentric distance step 18, bin-center distance is 98.53 AU
# Geocentric distance step 19, bin-center distance is 147.79 AU
# Across all geobins, identified 0 total linkages
# This hypothesis: 0 deduplicated linkages; total now 0 linkages totalling 0 detections.
# Working on hypothesis 8: 1.50 AU, 4.59 km/sec 0.02 GMsun/r^2
# 5 input pairs/tracklets led to 5 physically reasonable state vectors
# Geocentric distance step 1, bin-center distance is 0.10 AU
# Geocentric distance step 2, bin-center distance is 0.15 AU
# Geocentric distance step 3, bin-center distance is 0.23 AU
# Geocentric distance step 4, bin-center distance is 0.34 AU
# Geocentric distance step 5, bin-center distance is 0.51 AU
# KDRclust_6i01 finished clustering geobin 5, with 0 = 0 clusters found
# Final analysis of geobin 5 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 6, bin-center distance is 0.76 AU
# KDRclust_6i01 finished clustering geobin 6, with 0 = 0 clusters found
# Final analysis of geobin 6 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 7, bin-center distance is 1.14 AU
# Geocentric distance step 8, bin-center distance is 1.71 AU
# Geocentric distance step 9, bin-center distance is 2.56 AU
# Geocentric distance step 10, bin-center distance is 3.84 AU
# Geocentric distance step 11, bin-center distance is 5.77 AU
# Geocentric distance step 12, bin-center distance is 8.65 AU
# Geocentric distance step 13, bin-center distance is 12.97 AU
# Geocentric distance step 14, bin-center distance is 19.46 AU
# Geocentric distance step 15, bin-center distance is 29.19 AU
# Geocentric distance step 16, bin-center distance is 43.79 AU
# Geocentric distance step 17, bin-center distance is 65.68 AU
# Geocentric distance step 18, bin-center distance is 98.53 AU
# Geocentric distance step 19, bin-center distance is 147.79 AU
# Across all geobins, identified 0 total linkages
# This hypothesis: 0 deduplicated linkages; total now 0 linkages totalling 0 detections.
# Working on hypothesis 9: 1.50 AU, 9.17 km/sec 0.07 GMsun/r^2
# 5 input pairs/tracklets led to 5 physically reasonable state vectors
# Geocentric distance step 1, bin-center distance is 0.10 AU
# Geocentric distance step 2, bin-center distance is 0.15 AU
# Geocentric distance step 3, bin-center distance is 0.23 AU
# Geocentric distance step 4, bin-center distance is 0.34 AU
# Geocentric distance step 5, bin-center distance is 0.51 AU
# KDRclust_6i01 finished clustering geobin 5, with 0 = 0 clusters found
# Final analysis of geobin 5 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 6, bin-center distance is 0.76 AU
# KDRclust_6i01 finished clustering geobin 6, with 0 = 0 clusters found
# Final analysis of geobin 6 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 7, bin-center distance is 1.14 AU
# Geocentric distance step 8, bin-center distance is 1.71 AU
# Geocentric distance step 9, bin-center distance is 2.56 AU
# Geocentric distance step 10, bin-center distance is 3.84 AU
# Geocentric distance step 11, bin-center distance is 5.77 AU
# Geocentric distance step 12, bin-center distance is 8.65 AU
# Geocentric distance step 13, bin-center distance is 12.97 AU
# Geocentric distance step 14, bin-center distance is 19.46 AU
# Geocentric distance step 15, bin-center distance is 29.19 AU
# Geocentric distance step 16, bin-center distance is 43.79 AU
# Geocentric distance step 17, bin-center distance is 65.68 AU
# Geocentric distance step 18, bin-center distance is 98.53 AU
# Geocentric distance step 19, bin-center distance is 147.79 AU
# Across all geobins, identified 0 total linkages
# This hypothesis: 0 deduplicated linkages; total now 0 linkages totalling 0 detections.
# Working on hypothesis 10: 1.50 AU, 13.76 km/sec 0.16 GMsun/r^2
# 5 input pairs/tracklets led to 5 physically reasonable state vectors
# Geocentric distance step 1, bin-center distance is 0.10 AU
# Geocentric distance step 2, bin-center distance is 0.15 AU
# Geocentric distance step 3, bin-center distance is 0.23 AU
# Geocentric distance step 4, bin-center distance is 0.34 AU
# Geocentric distance step 5, bin-center distance is 0.51 AU
# KDRclust_6i01 finished clustering geobin 5, with 0 = 0 clusters found
# Final analysis of geobin 5 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 6, bin-center distance is 0.76 AU
# KDRclust_6i01 finished clustering geobin 6, with 0 = 0 clusters found
# Final analysis of geobin 6 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 7, bin-center distance is 1.14 AU
# Geocentric distance step 8, bin-center distance is 1.71 AU
# Geocentric distance step 9, bin-center distance is 2.56 AU
# Geocentric distance step 10, bin-center distance is 3.84 AU
# Geocentric distance step 11, bin-center distance is 5.77 AU
# Geocentric distance step 12, bin-center distance is 8.65 AU
# Geocentric distance step 13, bin-center distance is 12.97 AU
# Geocentric distance step 14, bin-center distance is 19.46 AU
# Geocentric distance step 15, bin-center distance is 29.19 AU
# Geocentric distance step 16, bin-center distance is 43.79 AU
# Geocentric distance step 17, bin-center distance is 65.68 AU
# Geocentric distance step 18, bin-center distance is 98.53 AU
# Geocentric distance step 19, bin-center distance is 147.79 AU
# Across all geobins, identified 0 total linkages
# This hypothesis: 0 deduplicated linkages; total now 0 linkages totalling 0 detections.
# Working on hypothesis 11: 1.50 AU, 18.34 km/sec 0.28 GMsun/r^2
# Working on hypothesis 12: 1.50 AU, 22.93 km/sec 0.44 GMsun/r^2
# Working on hypothesis 13: 1.50 AU, 27.51 km/sec 0.64 GMsun/r^2
# Working on hypothesis 14: 1.50 AU, 32.10 km/sec 0.87 GMsun/r^2
# Working on hypothesis 15: 1.69 AU, -27.76 km/sec 0.73 GMsun/r^2
# 5 input pairs/tracklets led to 5 physically reasonable state vectors
# Geocentric distance step 1, bin-center distance is 0.10 AU
# Geocentric distance step 2, bin-center distance is 0.15 AU
# Geocentric distance step 3, bin-center distance is 0.23 AU
# Geocentric distance step 4, bin-center distance is 0.34 AU
# Geocentric distance step 5, bin-center distance is 0.51 AU
# Geocentric distance step 6, bin-center distance is 0.76 AU
# KDRclust_6i01 finished clustering geobin 6, with 0 = 0 clusters found
# Final analysis of geobin 6 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 7, bin-center distance is 1.14 AU
# KDRclust_6i01 finished clustering geobin 7, with 0 = 0 clusters found
# Final analysis of geobin 7 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 8, bin-center distance is 1.71 AU
# Geocentric distance step 9, bin-center distance is 2.56 AU
# Geocentric distance step 10, bin-center distance is 3.84 AU
# Geocentric distance step 11, bin-center distance is 5.77 AU
# Geocentric distance step 12, bin-center distance is 8.65 AU
# Geocentric distance step 13, bin-center distance is 12.97 AU
# Geocentric distance step 14, bin-center distance is 19.46 AU
# Geocentric distance step 15, bin-center distance is 29.19 AU
# Geocentric distance step 16, bin-center distance is 43.79 AU
# Geocentric distance step 17, bin-center distance is 65.68 AU
# Geocentric distance step 18, bin-center distance is 98.53 AU
# Geocentric distance step 19, bin-center distance is 147.79 AU
# Across all geobins, identified 0 total linkages
# This hypothesis: 0 deduplicated linkages; total now 0 linkages totalling 0 detections.
# Working on hypothesis 16: 1.69 AU, -18.50 km/sec 0.33 GMsun/r^2
# 5 input pairs/tracklets led to 5 physically reasonable state vectors
# Geocentric distance step 1, bin-center distance is 0.10 AU
# Geocentric distance step 2, bin-center distance is 0.15 AU
# Geocentric distance step 3, bin-center distance is 0.23 AU
# Geocentric distance step 4, bin-center distance is 0.34 AU
# Geocentric distance step 5, bin-center distance is 0.51 AU
# Geocentric distance step 6, bin-center distance is 0.76 AU
# KDRclust_6i01 finished clustering geobin 6, with 0 = 0 clusters found
# Final analysis of geobin 6 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 7, bin-center distance is 1.14 AU
# KDRclust_6i01 finished clustering geobin 7, with 0 = 0 clusters found
# Final analysis of geobin 7 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 8, bin-center distance is 1.71 AU
# Geocentric distance step 9, bin-center distance is 2.56 AU
# Geocentric distance step 10, bin-center distance is 3.84 AU
# Geocentric distance step 11, bin-center distance is 5.77 AU
# Geocentric distance step 12, bin-center distance is 8.65 AU
# Geocentric distance step 13, bin-center distance is 12.97 AU
# Geocentric distance step 14, bin-center distance is 19.46 AU
# Geocentric distance step 15, bin-center distance is 29.19 AU
# Geocentric distance step 16, bin-center distance is 43.79 AU
# Geocentric distance step 17, bin-center distance is 65.68 AU
# Geocentric distance step 18, bin-center distance is 98.53 AU
# Geocentric distance step 19, bin-center distance is 147.79 AU
# Across all geobins, identified 0 total linkages
# This hypothesis: 0 deduplicated linkages; total now 0 linkages totalling 0 detections.
# Working on hypothesis 17: 1.69 AU, -9.25 km/sec 0.08 GMsun/r^2
# 5 input pairs/tracklets led to 5 physically reasonable state vectors
# Geocentric distance step 1, bin-center distance is 0.10 AU
# Geocentric distance step 2, bin-center distance is 0.15 AU
# Geocentric distance step 3, bin-center distance is 0.23 AU
# Geocentric distance step 4, bin-center distance is 0.34 AU
# Geocentric distance step 5, bin-center distance is 0.51 AU
# Geocentric distance step 6, bin-center distance is 0.76 AU
# KDRclust_6i01 finished clustering geobin 6, with 0 = 0 clusters found
# Final analysis of geobin 6 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 7, bin-center distance is 1.14 AU
# KDRclust_6i01 finished clustering geobin 7, with 0 = 0 clusters found
# Final analysis of geobin 7 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 8, bin-center distance is 1.71 AU
# Geocentric distance step 9, bin-center distance is 2.56 AU
# Geocentric distance step 10, bin-center distance is 3.84 AU
# Geocentric distance step 11, bin-center distance is 5.77 AU
# Geocentric distance step 12, bin-center distance is 8.65 AU
# Geocentric distance step 13, bin-center distance is 12.97 AU
# Geocentric distance step 14, bin-center distance is 19.46 AU
# Geocentric distance step 15, bin-center distance is 29.19 AU
# Geocentric distance step 16, bin-center distance is 43.79 AU
# Geocentric distance step 17, bin-center distance is 65.68 AU
# Geocentric distance step 18, bin-center distance is 98.53 AU
# Geocentric distance step 19, bin-center distance is 147.79 AU
# Across all geobins, identified 0 total linkages
# This hypothesis: 0 deduplicated linkages; total now 0 linkages totalling 0 detections.
# Working on hypothesis 18: 1.69 AU, 0.00 km/sec 0.00 GMsun/r^2
# 5 input pairs/tracklets led to 5 physically reasonable state vectors
# Geocentric distance step 1, bin-center distance is 0.10 AU
# Geocentric distance step 2, bin-center distance is 0.15 AU
# Geocentric distance step 3, bin-center distance is 0.23 AU
# Geocentric distance step 4, bin-center distance is 0.34 AU
# Geocentric distance step 5, bin-center distance is 0.51 AU
# Geocentric distance step 6, bin-center distance is 0.76 AU
# KDRclust_6i01 finished clustering geobin 6, with 0 = 0 clusters found
# Final analysis of geobin 6 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 7, bin-center distance is 1.14 AU
# KDRclust_6i01 finished clustering geobin 7, with 0 = 0 clusters found
# Final analysis of geobin 7 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 8, bin-center distance is 1.71 AU
# Geocentric distance step 9, bin-center distance is 2.56 AU
# Geocentric distance step 10, bin-center distance is 3.84 AU
# Geocentric distance step 11, bin-center distance is 5.77 AU
# Geocentric distance step 12, bin-center distance is 8.65 AU
# Geocentric distance step 13, bin-center distance is 12.97 AU
# Geocentric distance step 14, bin-center distance is 19.46 AU
# Geocentric distance step 15, bin-center distance is 29.19 AU
# Geocentric distance step 16, bin-center distance is 43.79 AU
# Geocentric distance step 17, bin-center distance is 65.68 AU
# Geocentric distance step 18, bin-center distance is 98.53 AU
# Geocentric distance step 19, bin-center distance is 147.79 AU
# Across all geobins, identified 0 total linkages
# This hypothesis: 0 deduplicated linkages; total now 0 linkages totalling 0 detections.
# Working on hypothesis 19: 1.69 AU, 9.25 km/sec 0.08 GMsun/r^2
# 5 input pairs/tracklets led to 5 physically reasonable state vectors
# Geocentric distance step 1, bin-center distance is 0.10 AU
# Geocentric distance step 2, bin-center distance is 0.15 AU
# Geocentric distance step 3, bin-center distance is 0.23 AU
# Geocentric distance step 4, bin-center distance is 0.34 AU
# Geocentric distance step 5, bin-center distance is 0.51 AU
# Geocentric distance step 6, bin-center distance is 0.76 AU
# KDRclust_6i01 finished clustering geobin 6, with 0 = 0 clusters found
# Final analysis of geobin 6 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 7, bin-center distance is 1.14 AU
# KDRclust_6i01 finished clustering geobin 7, with 0 = 0 clusters found
# Final analysis of geobin 7 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 8, bin-center distance is 1.71 AU
# Geocentric distance step 9, bin-center distance is 2.56 AU
# Geocentric distance step 10, bin-center distance is 3.84 AU
# Geocentric distance step 11, bin-center distance is 5.77 AU
# Geocentric distance step 12, bin-center distance is 8.65 AU
# Geocentric distance step 13, bin-center distance is 12.97 AU
# Geocentric distance step 14, bin-center distance is 19.46 AU
# Geocentric distance step 15, bin-center distance is 29.19 AU
# Geocentric distance step 16, bin-center distance is 43.79 AU
# Geocentric distance step 17, bin-center distance is 65.68 AU
# Geocentric distance step 18, bin-center distance is 98.53 AU
# Geocentric distance step 19, bin-center distance is 147.79 AU
# Across all geobins, identified 0 total linkages
# This hypothesis: 0 deduplicated linkages; total now 0 linkages totalling 0 detections.
# Working on hypothesis 20: 1.69 AU, 18.50 km/sec 0.33 GMsun/r^2
# Working on hypothesis 21: 1.69 AU, 27.76 km/sec 0.73 GMsun/r^2
# Working on hypothesis 22: 1.80 AU, -25.10 km/sec 0.64 GMsun/r^2
# 5 input pairs/tracklets led to 5 physically reasonable state vectors
# Geocentric distance step 1, bin-center distance is 0.10 AU
# Geocentric distance step 2, bin-center distance is 0.15 AU
# Geocentric distance step 3, bin-center distance is 0.23 AU
# Geocentric distance step 4, bin-center distance is 0.34 AU
# Geocentric distance step 5, bin-center distance is 0.51 AU
# Geocentric distance step 6, bin-center distance is 0.76 AU
# KDRclust_6i01 finished clustering geobin 6, with 0 = 0 clusters found
# Final analysis of geobin 6 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 7, bin-center distance is 1.14 AU
# KDRclust_6i01 finished clustering geobin 7, with 0 = 0 clusters found
# Final analysis of geobin 7 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 8, bin-center distance is 1.71 AU
# Geocentric distance step 9, bin-center distance is 2.56 AU
# Geocentric distance step 10, bin-center distance is 3.84 AU
# Geocentric distance step 11, bin-center distance is 5.77 AU
# Geocentric distance step 12, bin-center distance is 8.65 AU
# Geocentric distance step 13, bin-center distance is 12.97 AU
# Geocentric distance step 14, bin-center distance is 19.46 AU
# Geocentric distance step 15, bin-center distance is 29.19 AU
# Geocentric distance step 16, bin-center distance is 43.79 AU
# Geocentric distance step 17, bin-center distance is 65.68 AU
# Geocentric distance step 18, bin-center distance is 98.53 AU
# Geocentric distance step 19, bin-center distance is 147.79 AU
# Across all geobins, identified 0 total linkages
# This hypothesis: 0 deduplicated linkages; total now 0 linkages totalling 0 detections.
# Working on hypothesis 23: 1.80 AU, -12.55 km/sec 0.16 GMsun/r^2
# 5 input pairs/tracklets led to 5 physically reasonable state vectors
# Geocentric distance step 1, bin-center distance is 0.10 AU
# Geocentric distance step 2, bin-center distance is 0.15 AU
# Geocentric distance step 3, bin-center distance is 0.23 AU
# Geocentric distance step 4, bin-center distance is 0.34 AU
# Geocentric distance step 5, bin-center distance is 0.51 AU
# Geocentric distance step 6, bin-center distance is 0.76 AU
# KDRclust_6i01 finished clustering geobin 6, with 0 = 0 clusters found
# Final analysis of geobin 6 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 7, bin-center distance is 1.14 AU
# KDRclust_6i01 finished clustering geobin 7, with 0 = 0 clusters found
# Final analysis of geobin 7 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 8, bin-center distance is 1.71 AU
# Geocentric distance step 9, bin-center distance is 2.56 AU
# Geocentric distance step 10, bin-center distance is 3.84 AU
# Geocentric distance step 11, bin-center distance is 5.77 AU
# Geocentric distance step 12, bin-center distance is 8.65 AU
# Geocentric distance step 13, bin-center distance is 12.97 AU
# Geocentric distance step 14, bin-center distance is 19.46 AU
# Geocentric distance step 15, bin-center distance is 29.19 AU
# Geocentric distance step 16, bin-center distance is 43.79 AU
# Geocentric distance step 17, bin-center distance is 65.68 AU
# Geocentric distance step 18, bin-center distance is 98.53 AU
# Geocentric distance step 19, bin-center distance is 147.79 AU
# Across all geobins, identified 0 total linkages
# This hypothesis: 0 deduplicated linkages; total now 0 linkages totalling 0 detections.
# Working on hypothesis 24: 1.80 AU, 0.00 km/sec 0.00 GMsun/r^2
# 5 input pairs/tracklets led to 5 physically reasonable state vectors
# Geocentric distance step 1, bin-center distance is 0.10 AU
# Geocentric distance step 2, bin-center distance is 0.15 AU
# Geocentric distance step 3, bin-center distance is 0.23 AU
# Geocentric distance step 4, bin-center distance is 0.34 AU
# Geocentric distance step 5, bin-center distance is 0.51 AU
# Geocentric distance step 6, bin-center distance is 0.76 AU
# KDRclust_6i01 finished clustering geobin 6, with 0 = 0 clusters found
# Final analysis of geobin 6 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 7, bin-center distance is 1.14 AU
# KDRclust_6i01 finished clustering geobin 7, with 0 = 0 clusters found
# Final analysis of geobin 7 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 8, bin-center distance is 1.71 AU
# Geocentric distance step 9, bin-center distance is 2.56 AU
# Geocentric distance step 10, bin-center distance is 3.84 AU
# Geocentric distance step 11, bin-center distance is 5.77 AU
# Geocentric distance step 12, bin-center distance is 8.65 AU
# Geocentric distance step 13, bin-center distance is 12.97 AU
# Geocentric distance step 14, bin-center distance is 19.46 AU
# Geocentric distance step 15, bin-center distance is 29.19 AU
# Geocentric distance step 16, bin-center distance is 43.79 AU
# Geocentric distance step 17, bin-center distance is 65.68 AU
# Geocentric distance step 18, bin-center distance is 98.53 AU
# Geocentric distance step 19, bin-center distance is 147.79 AU
# Across all geobins, identified 0 total linkages
# This hypothesis: 0 deduplicated linkages; total now 0 linkages totalling 0 detections.
# Working on hypothesis 25: 1.80 AU, 12.55 km/sec 0.16 GMsun/r^2
# 5 input pairs/tracklets led to 5 physically reasonable state vectors
# Geocentric distance step 1, bin-center distance is 0.10 AU
# Geocentric distance step 2, bin-center distance is 0.15 AU
# Geocentric distance step 3, bin-center distance is 0.23 AU
# Geocentric distance step 4, bin-center distance is 0.34 AU
# Geocentric distance step 5, bin-center distance is 0.51 AU
# Geocentric distance step 6, bin-center distance is 0.76 AU
# KDRclust_6i01 finished clustering geobin 6, with 0 = 0 clusters found
# Final analysis of geobin 6 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 7, bin-center distance is 1.14 AU
# KDRclust_6i01 finished clustering geobin 7, with 0 = 0 clusters found
# Final analysis of geobin 7 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 8, bin-center distance is 1.71 AU
# Geocentric distance step 9, bin-center distance is 2.56 AU
# Geocentric distance step 10, bin-center distance is 3.84 AU
# Geocentric distance step 11, bin-center distance is 5.77 AU
# Geocentric distance step 12, bin-center distance is 8.65 AU
# Geocentric distance step 13, bin-center distance is 12.97 AU
# Geocentric distance step 14, bin-center distance is 19.46 AU
# Geocentric distance step 15, bin-center distance is 29.19 AU
# Geocentric distance step 16, bin-center distance is 43.79 AU
# Geocentric distance step 17, bin-center distance is 65.68 AU
# Geocentric distance step 18, bin-center distance is 98.53 AU
# Geocentric distance step 19, bin-center distance is 147.79 AU
# Across all geobins, identified 0 total linkages
# This hypothesis: 0 deduplicated linkages; total now 0 linkages totalling 0 detections.
# Working on hypothesis 26: 1.80 AU, 25.10 km/sec 0.64 GMsun/r^2
# Working on hypothesis 27: 1.93 AU, -24.26 km/sec 0.64 GMsun/r^2
# 5 input pairs/tracklets led to 5 physically reasonable state vectors
# Geocentric distance step 1, bin-center distance is 0.10 AU
# Geocentric distance step 2, bin-center distance is 0.15 AU
# Geocentric distance step 3, bin-center distance is 0.23 AU
# Geocentric distance step 4, bin-center distance is 0.34 AU
# Geocentric distance step 5, bin-center distance is 0.51 AU
# Geocentric distance step 6, bin-center distance is 0.76 AU
# Geocentric distance step 7, bin-center distance is 1.14 AU
# KDRclust_6i01 finished clustering geobin 7, with 0 = 0 clusters found
# Final analysis of geobin 7 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 8, bin-center distance is 1.71 AU
# KDRclust_6i01 finished clustering geobin 8, with 0 = 0 clusters found
# Final analysis of geobin 8 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 9, bin-center distance is 2.56 AU
# Geocentric distance step 10, bin-center distance is 3.84 AU
# Geocentric distance step 11, bin-center distance is 5.77 AU
# Geocentric distance step 12, bin-center distance is 8.65 AU
# Geocentric distance step 13, bin-center distance is 12.97 AU
# Geocentric distance step 14, bin-center distance is 19.46 AU
# Geocentric distance step 15, bin-center distance is 29.19 AU
# Geocentric distance step 16, bin-center distance is 43.79 AU
# Geocentric distance step 17, bin-center distance is 65.68 AU
# Geocentric distance step 18, bin-center distance is 98.53 AU
# Geocentric distance step 19, bin-center distance is 147.79 AU
# Across all geobins, identified 0 total linkages
# This hypothesis: 0 deduplicated linkages; total now 0 linkages totalling 0 detections.
# Working on hypothesis 28: 1.93 AU, -12.13 km/sec 0.16 GMsun/r^2
# 5 input pairs/tracklets led to 5 physically reasonable state vectors
# Geocentric distance step 1, bin-center distance is 0.10 AU
# Geocentric distance step 2, bin-center distance is 0.15 AU
# Geocentric distance step 3, bin-center distance is 0.23 AU
# Geocentric distance step 4, bin-center distance is 0.34 AU
# Geocentric distance step 5, bin-center distance is 0.51 AU
# Geocentric distance step 6, bin-center distance is 0.76 AU
# Geocentric distance step 7, bin-center distance is 1.14 AU
# KDRclust_6i01 finished clustering geobin 7, with 0 = 0 clusters found
# Final analysis of geobin 7 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 8, bin-center distance is 1.71 AU
# KDRclust_6i01 finished clustering geobin 8, with 0 = 0 clusters found
# Final analysis of geobin 8 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 9, bin-center distance is 2.56 AU
# Geocentric distance step 10, bin-center distance is 3.84 AU
# Geocentric distance step 11, bin-center distance is 5.77 AU
# Geocentric distance step 12, bin-center distance is 8.65 AU
# Geocentric distance step 13, bin-center distance is 12.97 AU
# Geocentric distance step 14, bin-center distance is 19.46 AU
# Geocentric distance step 15, bin-center distance is 29.19 AU
# Geocentric distance step 16, bin-center distance is 43.79 AU
# Geocentric distance step 17, bin-center distance is 65.68 AU
# Geocentric distance step 18, bin-center distance is 98.53 AU
# Geocentric distance step 19, bin-center distance is 147.79 AU
# Across all geobins, identified 0 total linkages
# This hypothesis: 0 deduplicated linkages; total now 0 linkages totalling 0 detections.
# Working on hypothesis 29: 1.93 AU, 0.00 km/sec 0.00 GMsun/r^2
# 5 input pairs/tracklets led to 5 physically reasonable state vectors
# Geocentric distance step 1, bin-center distance is 0.10 AU
# Geocentric distance step 2, bin-center distance is 0.15 AU
# Geocentric distance step 3, bin-center distance is 0.23 AU
# Geocentric distance step 4, bin-center distance is 0.34 AU
# Geocentric distance step 5, bin-center distance is 0.51 AU
# Geocentric distance step 6, bin-center distance is 0.76 AU
# Geocentric distance step 7, bin-center distance is 1.14 AU
# KDRclust_6i01 finished clustering geobin 7, with 0 = 0 clusters found
# Final analysis of geobin 7 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 8, bin-center distance is 1.71 AU
# KDRclust_6i01 finished clustering geobin 8, with 0 = 0 clusters found
# Final analysis of geobin 8 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 9, bin-center distance is 2.56 AU
# Geocentric distance step 10, bin-center distance is 3.84 AU
# Geocentric distance step 11, bin-center distance is 5.77 AU
# Geocentric distance step 12, bin-center distance is 8.65 AU
# Geocentric distance step 13, bin-center distance is 12.97 AU
# Geocentric distance step 14, bin-center distance is 19.46 AU
# Geocentric distance step 15, bin-center distance is 29.19 AU
# Geocentric distance step 16, bin-center distance is 43.79 AU
# Geocentric distance step 17, bin-center distance is 65.68 AU
# Geocentric distance step 18, bin-center distance is 98.53 AU
# Geocentric distance step 19, bin-center distance is 147.79 AU
# Across all geobins, identified 0 total linkages
# This hypothesis: 0 deduplicated linkages; total now 0 linkages totalling 0 detections.
# Working on hypothesis 30: 1.93 AU, 12.13 km/sec 0.16 GMsun/r^2
# 5 input pairs/tracklets led to 4 physically reasonable state vectors
# Geocentric distance step 1, bin-center distance is 0.10 AU
# Geocentric distance step 2, bin-center distance is 0.15 AU
# Geocentric distance step 3, bin-center distance is 0.23 AU
# Geocentric distance step 4, bin-center distance is 0.34 AU
# Geocentric distance step 5, bin-center distance is 0.51 AU
# Geocentric distance step 6, bin-center distance is 0.76 AU
# Geocentric distance step 7, bin-center distance is 1.14 AU
# KDRclust_6i01 finished clustering geobin 7, with 0 = 0 clusters found
# Final analysis of geobin 7 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 8, bin-center distance is 1.71 AU
# KDRclust_6i01 finished clustering geobin 8, with 0 = 0 clusters found
# Final analysis of geobin 8 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 9, bin-center distance is 2.56 AU
# Geocentric distance step 10, bin-center distance is 3.84 AU
# Geocentric distance step 11, bin-center distance is 5.77 AU
# Geocentric distance step 12, bin-center distance is 8.65 AU
# Geocentric distance step 13, bin-center distance is 12.97 AU
# Geocentric distance step 14, bin-center distance is 19.46 AU
# Geocentric distance step 15, bin-center distance is 29.19 AU
# Geocentric distance step 16, bin-center distance is 43.79 AU
# Geocentric distance step 17, bin-center distance is 65.68 AU
# Geocentric distance step 18, bin-center distance is 98.53 AU
# Geocentric distance step 19, bin-center distance is 147.79 AU
# Across all geobins, identified 0 total linkages
# This hypothesis: 0 deduplicated linkages; total now 0 linkages totalling 0 detections.
# Working on hypothesis 31: 1.93 AU, 24.26 km/sec 0.64 GMsun/r^2
# Working on hypothesis 32: 2.07 AU, -19.51 km/sec 0.44 GMsun/r^2
# 5 input pairs/tracklets led to 5 physically reasonable state vectors
# Geocentric distance step 1, bin-center distance is 0.10 AU
# Geocentric distance step 2, bin-center distance is 0.15 AU
# Geocentric distance step 3, bin-center distance is 0.23 AU
# Geocentric distance step 4, bin-center distance is 0.34 AU
# Geocentric distance step 5, bin-center distance is 0.51 AU
# Geocentric distance step 6, bin-center distance is 0.76 AU
# Geocentric distance step 7, bin-center distance is 1.14 AU
# KDRclust_6i01 finished clustering geobin 7, with 0 = 0 clusters found
# Final analysis of geobin 7 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 8, bin-center distance is 1.71 AU
# KDRclust_6i01 finished clustering geobin 8, with 0 = 0 clusters found
# Final analysis of geobin 8 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 9, bin-center distance is 2.56 AU
# Geocentric distance step 10, bin-center distance is 3.84 AU
# Geocentric distance step 11, bin-center distance is 5.77 AU
# Geocentric distance step 12, bin-center distance is 8.65 AU
# Geocentric distance step 13, bin-center distance is 12.97 AU
# Geocentric distance step 14, bin-center distance is 19.46 AU
# Geocentric distance step 15, bin-center distance is 29.19 AU
# Geocentric distance step 16, bin-center distance is 43.79 AU
# Geocentric distance step 17, bin-center distance is 65.68 AU
# Geocentric distance step 18, bin-center distance is 98.53 AU
# Geocentric distance step 19, bin-center distance is 147.79 AU
# Across all geobins, identified 0 total linkages
# This hypothesis: 0 deduplicated linkages; total now 0 linkages totalling 0 detections.
# Working on hypothesis 33: 2.07 AU, 0.00 km/sec 0.00 GMsun/r^2
# 5 input pairs/tracklets led to 5 physically reasonable state vectors
# Geocentric distance step 1, bin-center distance is 0.10 AU
# Geocentric distance step 2, bin-center distance is 0.15 AU
# Geocentric distance step 3, bin-center distance is 0.23 AU
# Geocentric distance step 4, bin-center distance is 0.34 AU
# Geocentric distance step 5, bin-center distance is 0.51 AU
# Geocentric distance step 6, bin-center distance is 0.76 AU
# Geocentric distance step 7, bin-center distance is 1.14 AU
# KDRclust_6i01 finished clustering geobin 7, with 0 = 0 clusters found
# Final analysis of geobin 7 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 8, bin-center distance is 1.71 AU
# ...
# Geocentric distance step 10, bin-center distance is 3.84 AU
# Geocentric distance step 11, bin-center distance is 5.77 AU
# Geocentric distance step 12, bin-center distance is 8.65 AU
# Geocentric distance step 13, bin-center distance is 12.97 AU
# Geocentric distance step 14, bin-center distance is 19.46 AU
# Geocentric distance step 15, bin-center distance is 29.19 AU
# Geocentric distance step 16, bin-center distance is 43.79 AU
# Geocentric distance step 17, bin-center distance is 65.68 AU
# Geocentric distance step 18, bin-center distance is 98.53 AU
# Geocentric distance step 19, bin-center distance is 147.79 AU
# Across all geobins, identified 0 total linkages
# This hypothesis: 0 deduplicated linkages; total now 0 linkages totalling 0 detections.
# Working on hypothesis 33: 2.07 AU, 0.00 km/sec 0.00 GMsun/r^2
# 15 input pairs/tracklets led to 11 physically reasonable state vectors
# Geocentric distance step 1, bin-center distance is 0.10 AU
# Geocentric distance step 2, bin-center distance is 0.15 AU
# Geocentric distance step 3, bin-center distance is 0.23 AU
# Geocentric distance step 4, bin-center distance is 0.34 AU
# Geocentric distance step 5, bin-center distance is 0.51 AU
# Geocentric distance step 6, bin-center distance is 0.76 AU
# Geocentric distance step 7, bin-center distance is 1.14 AU
# KDRclust_6i01 finished clustering geobin 7, with 0 = 0 clusters found
# Final analysis of geobin 7 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 8, bin-center distance is 1.71 AU
# KDRclust_6i01 finished clustering geobin 8, with 0 = 0 clusters found
# Final analysis of geobin 8 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 9, bin-center distance is 2.56 AU
# Geocentric distance step 10, bin-center distance is 3.84 AU
# Geocentric distance step 11, bin-center distance is 5.77 AU
# Geocentric distance step 12, bin-center distance is 8.65 AU
# Geocentric distance step 13, bin-center distance is 12.97 AU
# Geocentric distance step 14, bin-center distance is 19.46 AU
# Geocentric distance step 15, bin-center distance is 29.19 AU
# Geocentric distance step 16, bin-center distance is 43.79 AU
# Geocentric distance step 17, bin-center distance is 65.68 AU
# Geocentric distance step 18, bin-center distance is 98.53 AU
# Geocentric distance step 19, bin-center distance is 147.79 AU
# Across all geobins, identified 0 total linkages
# This hypothesis: 0 deduplicated linkages; total now 0 linkages totalling 0 detections.
# Working on hypothesis 34: 2.07 AU, 19.51 km/sec 0.44 GMsun/r^2
# Working on hypothesis 35: 2.23 AU, -18.82 km/sec 0.44 GMsun/r^2
# 15 input pairs/tracklets led to 11 physically reasonable state vectors
# Geocentric distance step 1, bin-center distance is 0.10 AU
# Geocentric distance step 2, bin-center distance is 0.15 AU
# Geocentric distance step 3, bin-center distance is 0.23 AU
# Geocentric distance step 4, bin-center distance is 0.34 AU
# Geocentric distance step 5, bin-center distance is 0.51 AU
# Geocentric distance step 6, bin-center distance is 0.76 AU
# Geocentric distance step 7, bin-center distance is 1.14 AU
# KDRclust_6i01 finished clustering geobin 7, with 0 = 0 clusters found
# Final analysis of geobin 7 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 8, bin-center distance is 1.71 AU
# KDRclust_6i01 finished clustering geobin 8, with 0 = 0 clusters found
# Final analysis of geobin 8 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 9, bin-center distance is 2.56 AU
# Geocentric distance step 10, bin-center distance is 3.84 AU
# Geocentric distance step 11, bin-center distance is 5.77 AU
# Geocentric distance step 12, bin-center distance is 8.65 AU
# Geocentric distance step 13, bin-center distance is 12.97 AU
# Geocentric distance step 14, bin-center distance is 19.46 AU
# Geocentric distance step 15, bin-center distance is 29.19 AU
# Geocentric distance step 16, bin-center distance is 43.79 AU
# Geocentric distance step 17, bin-center distance is 65.68 AU
# Geocentric distance step 18, bin-center distance is 98.53 AU
# Geocentric distance step 19, bin-center distance is 147.79 AU
# Across all geobins, identified 0 total linkages
# This hypothesis: 0 deduplicated linkages; total now 0 linkages totalling 0 detections.
# Working on hypothesis 36: 2.23 AU, 0.00 km/sec 0.00 GMsun/r^2
# 15 input pairs/tracklets led to 9 physically reasonable state vectors
# Geocentric distance step 1, bin-center distance is 0.10 AU
# Geocentric distance step 2, bin-center distance is 0.15 AU
# Geocentric distance step 3, bin-center distance is 0.23 AU
# Geocentric distance step 4, bin-center distance is 0.34 AU
# Geocentric distance step 5, bin-center distance is 0.51 AU
# Geocentric distance step 6, bin-center distance is 0.76 AU
# Geocentric distance step 7, bin-center distance is 1.14 AU
# KDRclust_6i01 finished clustering geobin 7, with 0 = 0 clusters found
# Final analysis of geobin 7 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 8, bin-center distance is 1.71 AU
# KDRclust_6i01 finished clustering geobin 8, with 0 = 0 clusters found
# Final analysis of geobin 8 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 9, bin-center distance is 2.56 AU
# Geocentric distance step 10, bin-center distance is 3.84 AU
# Geocentric distance step 11, bin-center distance is 5.77 AU
# Geocentric distance step 12, bin-center distance is 8.65 AU
# Geocentric distance step 13, bin-center distance is 12.97 AU
# Geocentric distance step 14, bin-center distance is 19.46 AU
# Geocentric distance step 15, bin-center distance is 29.19 AU
# Geocentric distance step 16, bin-center distance is 43.79 AU
# Geocentric distance step 17, bin-center distance is 65.68 AU
# Geocentric distance step 18, bin-center distance is 98.53 AU
# Geocentric distance step 19, bin-center distance is 147.79 AU
# Across all geobins, identified 0 total linkages
# This hypothesis: 0 deduplicated linkages; total now 0 linkages totalling 0 detections.
# Working on hypothesis 37: 2.23 AU, 18.82 km/sec 0.44 GMsun/r^2
# Working on hypothesis 38: 2.40 AU, -18.14 km/sec 0.44 GMsun/r^2
# 15 input pairs/tracklets led to 7 physically reasonable state vectors
# Geocentric distance step 1, bin-center distance is 0.10 AU
# Geocentric distance step 2, bin-center distance is 0.15 AU
# Geocentric distance step 3, bin-center distance is 0.23 AU
# Geocentric distance step 4, bin-center distance is 0.34 AU
# Geocentric distance step 5, bin-center distance is 0.51 AU
# Geocentric distance step 6, bin-center distance is 0.76 AU
# Geocentric distance step 7, bin-center distance is 1.14 AU
# Geocentric distance step 8, bin-center distance is 1.71 AU
# KDRclust_6i01 finished clustering geobin 8, with 0 = 0 clusters found
# Final analysis of geobin 8 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 9, bin-center distance is 2.56 AU
# KDRclust_6i01 finished clustering geobin 9, with 0 = 0 clusters found
# Final analysis of geobin 9 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 10, bin-center distance is 3.84 AU
# Geocentric distance step 11, bin-center distance is 5.77 AU
# Geocentric distance step 12, bin-center distance is 8.65 AU
# Geocentric distance step 13, bin-center distance is 12.97 AU
# Geocentric distance step 14, bin-center distance is 19.46 AU
# Geocentric distance step 15, bin-center distance is 29.19 AU
# Geocentric distance step 16, bin-center distance is 43.79 AU
# Geocentric distance step 17, bin-center distance is 65.68 AU
# Geocentric distance step 18, bin-center distance is 98.53 AU
# Geocentric distance step 19, bin-center distance is 147.79 AU
# Across all geobins, identified 0 total linkages
# This hypothesis: 0 deduplicated linkages; total now 0 linkages totalling 0 detections.
# Working on hypothesis 39: 2.40 AU, 0.00 km/sec 0.00 GMsun/r^2
# 15 input pairs/tracklets led to 5 physically reasonable state vectors
# Geocentric distance step 1, bin-center distance is 0.10 AU
# Geocentric distance step 2, bin-center distance is 0.15 AU
# Geocentric distance step 3, bin-center distance is 0.23 AU
# Geocentric distance step 4, bin-center distance is 0.34 AU
# Geocentric distance step 5, bin-center distance is 0.51 AU
# Geocentric distance step 6, bin-center distance is 0.76 AU
# Geocentric distance step 7, bin-center distance is 1.14 AU
# Geocentric distance step 8, bin-center distance is 1.71 AU
# KDRclust_6i01 finished clustering geobin 8, with 0 = 0 clusters found
# Final analysis of geobin 8 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 9, bin-center distance is 2.56 AU
# KDRclust_6i01 finished clustering geobin 9, with 0 = 0 clusters found
# Final analysis of geobin 9 identified 0 distinct candidate linkages. Current total is 0
# Geocentric distance step 10, bin-center distance is 3.84 AU
# Geocentric distance step 11, bin-center distance is 5.77 AU
# Geocentric distance step 12, bin-center distance is 8.65 AU
# Geocentric distance step 13, bin-center distance is 12.97 AU
# Geocentric distance step 14, bin-center distance is 19.46 AU
# Geocentric distance step 15, bin-center distance is 29.19 AU
# Geocentric distance step 16, bin-center distance is 43.79 AU
# Geocentric distance step 17, bin-center distance is 65.68 AU
# Geocentric distance step 18, bin-center distance is 98.53 AU
# Geocentric distance step 19, bin-center distance is 147.79 AU
# Across all geobins, identified 0 total linkages
# This hypothesis: 0 deduplicated linkages; total now 0 linkages totalling 0 detections.
# Working on hypothesis 40: 2.40 AU, 18.14 km/sec 0.44 GMsun/r^2
# Working on hypothesis 41: 2.59 AU, -17.43 km/sec 0.44 GMsun/r^2
# Working on hypothesis 42: 2.59 AU, 0.00 km/sec 0.00 GMsun/r^2
# Working on hypothesis 43: 2.59 AU, 17.43 km/sec 0.44 GMsun/r^2
# Working on hypothesis 44: 2.79 AU, -16.80 km/sec 0.44 GMsun/r^2
# Working on hypothesis 45: 2.79 AU, 0.00 km/sec 0.00 GMsun/r^2
# Working on hypothesis 46: 2.79 AU, 16.80 km/sec 0.44 GMsun/r^2
# Working on hypothesis 47: 3.02 AU, -16.16 km/sec 0.44 GMsun/r^2
# Working on hypothesis 48: 3.02 AU, 0.00 km/sec 0.00 GMsun/r^2
# Working on hypothesis 49: 3.02 AU, 16.16 km/sec 0.44 GMsun/r^2
# Working on hypothesis 50: 3.26 AU, -15.56 km/sec 0.44 GMsun/r^2
# Working on hypothesis 51: 3.26 AU, 0.00 km/sec 0.00 GMsun/r^2
# Working on hypothesis 52: 3.26 AU, 15.56 km/sec 0.44 GMsun/r^2
# Working on hypothesis 53: 3.51 AU, -14.99 km/sec 0.44 GMsun/r^2
# Working on hypothesis 54: 3.51 AU, 0.00 km/sec 0.00 GMsun/r^2
# Working on hypothesis 55: 3.51 AU, 14.99 km/sec 0.44 GMsun/r^2
# Working on hypothesis 56: 3.81 AU, -14.39 km/sec 0.44 GMsun/r^2
# Working on hypothesis 57: 3.81 AU, 0.00 km/sec 0.00 GMsun/r^2
# Working on hypothesis 58: 3.81 AU, 14.39 km/sec 0.44 GMsun/r^2
# Working on hypothesis 59: 4.11 AU, -13.85 km/sec 0.44 GMsun/r^2
# Working on hypothesis 60: 4.11 AU, 0.00 km/sec 0.00 GMsun/r^2
# Working on hypothesis 61: 4.11 AU, 13.85 km/sec 0.44 GMsun/r^2
# Working on hypothesis 62: 4.41 AU, -13.37 km/sec 0.44 GMsun/r^2
# Working on hypothesis 63: 4.41 AU, 0.00 km/sec 0.00 GMsun/r^2
# Working on hypothesis 64: 4.41 AU, 13.37 km/sec 0.44 GMsun/r^2
# Working on hypothesis 65: 4.71 AU, -12.94 km/sec 0.44 GMsun/r^2
# Working on hypothesis 66: 4.71 AU, 0.00 km/sec 0.00 GMsun/r^2
# Working on hypothesis 67: 4.71 AU, 12.94 km/sec 0.44 GMsun/r^2
# Working on hypothesis 68: 5.01 AU, -12.55 km/sec 0.44 GMsun/r^2
# Working on hypothesis 69: 5.01 AU, 0.00 km/sec 0.00 GMsun/r^2
# Working on hypothesis 70: 5.01 AU, 12.55 km/sec 0.44 GMsun/r^2
# Working on hypothesis 71: 5.31 AU, -12.19 km/sec 0.44 GMsun/r^2
# Working on hypothesis 72: 5.31 AU, 0.00 km/sec 0.00 GMsun/r^2
# Working on hypothesis 73: 5.31 AU, 12.19 km/sec 0.44 GMsun/r^2
# Working on hypothesis 74: 5.61 AU, -11.86 km/sec 0.44 GMsun/r^2
# Working on hypothesis 75: 5.61 AU, 0.00 km/sec 0.00 GMsun/r^2
# Working on hypothesis 76: 5.61 AU, 11.86 km/sec 0.44 GMsun/r^2
# Working on hypothesis 77: 5.91 AU, -11.55 km/sec 0.44 GMsun/r^2
# Working on hypothesis 78: 5.91 AU, 0.00 km/sec 0.00 GMsun/r^2
# Working on hypothesis 79: 5.91 AU, 11.55 km/sec 0.44 GMsun/r^2
# Working on hypothesis 80: 6.21 AU, -11.27 km/sec 0.44 GMsun/r^2
# Working on hypothesis 81: 6.21 AU, 0.00 km/sec 0.00 GMsun/r^2
# Working on hypothesis 82: 6.21 AU, 11.27 km/sec 0.44 GMsun/r^2
# Working on hypothesis 83: 6.51 AU, -11.01 km/sec 0.44 GMsun/r^2
# Working on hypothesis 84: 6.51 AU, 0.00 km/sec 0.00 GMsun/r^2
# Working on hypothesis 85: 6.51 AU, 11.01 km/sec 0.44 GMsun/r^2
# Working on hypothesis 86: 6.81 AU, -10.76 km/sec 0.44 GMsun/r^2
# Working on hypothesis 87: 6.81 AU, 0.00 km/sec 0.00 GMsun/r^2
# Working on hypothesis 88: 6.81 AU, 10.76 km/sec 0.44 GMsun/r^2
# Working on hypothesis 89: 7.11 AU, -10.53 km/sec 0.44 GMsun/r^2
# Working on hypothesis 90: 7.11 AU, 0.00 km/sec 0.00 GMsun/r^2
# Working on hypothesis 91: 7.11 AU, 10.53 km/sec 0.44 GMsun/r^2
# Working on hypothesis 92: 7.40 AU, -10.33 km/sec 0.44 GMsun/r^2
# Working on hypothesis 93: 7.40 AU, 0.00 km/sec 0.00 GMsun/r^2
# Working on hypothesis 94: 7.40 AU, 10.33 km/sec 0.44 GMsun/r^2
# Working on hypothesis 95: 7.65 AU, -10.15 km/sec 0.44 GMsun/r^2
# Working on hypothesis 96: 7.65 AU, 0.00 km/sec 0.00 GMsun/r^2
# Working on hypothesis 97: 7.65 AU, 10.15 km/sec 0.44 GMsun/r^2
# Working on hypothesis 98: 7.88 AU, -10.00 km/sec 0.44 GMsun/r^2
# Working on hypothesis 99: 7.88 AU, 0.00 km/sec 0.00 GMsun/r^2
# Working on hypothesis 100: 7.88 AU, 10.00 km/sec 0.44 GMsun/r^2
# Working on hypothesis 101: 8.09 AU, -11.85 km/sec 0.64 GMsun/r^2
# Working on hypothesis 102: 8.09 AU, -5.92 km/sec 0.16 GMsun/r^2
# Working on hypothesis 103: 8.09 AU, 0.00 km/sec 0.00 GMsun/r^2
# Working on hypothesis 104: 8.09 AU, 5.92 km/sec 0.16 GMsun/r^2
# Working on hypothesis 105: 8.09 AU, 11.85 km/sec 0.64 GMsun/r^2
# Working on hypothesis 106: 8.29 AU, -11.70 km/sec 0.64 GMsun/r^2
# Working on hypothesis 107: 8.29 AU, -5.85 km/sec 0.16 GMsun/r^2
# Working on hypothesis 108: 8.29 AU, 0.00 km/sec 0.00 GMsun/r^2
# Working on hypothesis 109: 8.29 AU, 5.85 km/sec 0.16 GMsun/r^2
# Working on hypothesis 110: 8.29 AU, 11.70 km/sec 0.64 GMsun/r^2
# Working on hypothesis 111: 8.49 AU, -9.64 km/sec 0.44 GMsun/r^2
# Working on hypothesis 112: 8.49 AU, 0.00 km/sec 0.00 GMsun/r^2
# Working on hypothesis 113: 8.49 AU, 9.64 km/sec 0.44 GMsun/r^2
# Working on hypothesis 114: 8.69 AU, -9.53 km/sec 0.44 GMsun/r^2
# Working on hypothesis 115: 8.69 AU, 0.00 km/sec 0.00 GMsun/r^2
# Working on hypothesis 116: 8.69 AU, 9.53 km/sec 0.44 GMsun/r^2
# Working on hypothesis 117: 8.89 AU, -9.42 km/sec 0.44 GMsun/r^2
# Working on hypothesis 118: 8.89 AU, 0.00 km/sec 0.00 GMsun/r^2
# Working on hypothesis 119: 8.89 AU, 9.42 km/sec 0.44 GMsun/r^2
# Working on hypothesis 120: 9.09 AU, -9.31 km/sec 0.44 GMsun/r^2
# Working on hypothesis 121: 9.09 AU, 0.00 km/sec 0.00 GMsun/r^2
# Working on hypothesis 122: 9.09 AU, 9.31 km/sec 0.44 GMsun/r^2
# Working on hypothesis 123: 9.29 AU, -9.21 km/sec 0.44 GMsun/r^2
# Working on hypothesis 124: 9.29 AU, 0.00 km/sec 0.00 GMsun/r^2
# Working on hypothesis 125: 9.29 AU, 9.21 km/sec 0.44 GMsun/r^2
# Working on hypothesis 126: 9.49 AU, -9.12 km/sec 0.44 GMsun/r^2
# Working on hypothesis 127: 9.49 AU, 0.00 km/sec 0.00 GMsun/r^2
# Working on hypothesis 128: 9.49 AU, 9.12 km/sec 0.44 GMsun/r^2
# Working on hypothesis 129: 9.69 AU, -9.02 km/sec 0.44 GMsun/r^2
# Working on hypothesis 130: 9.69 AU, 0.00 km/sec 0.00 GMsun/r^2
# Working on hypothesis 131: 9.69 AU, 9.02 km/sec 0.44 GMsun/r^2
# Working on hypothesis 132: 9.89 AU, -8.93 km/sec 0.44 GMsun/r^2
# Working on hypothesis 133: 9.89 AU, 0.00 km/sec 0.00 GMsun/r^2
# Working on hypothesis 134: 9.89 AU, 8.93 km/sec 0.44 GMsun/r^2
# De-duplicating output set of 0 candidate linkages totalling 0 detections
# Final de-duplicated set contains 0 linkages totalling 0 detections
# Automatically calculated reference MJD was 60363.85
# Writing 0 lines to output cluster-summary file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/sum_pratchett_ng_a3_3.0.csv
# Writing 0 lines to output clust2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/clust2det_pratchett_ng_a3_3.0.csv

# %%
## run link_purify -- first, create the lflist file

for m in range(len(ofnames)):
    with open('{0}{1}_lflist'.format(sfpath, ofnames[m]), 'w') as f:
        f.write("{0}sum_{1}.csv {0}clust2det_{1}.csv".format(sfpath, ofnames[m]))
        f.close()

        ## now, actually run link_purify
        subprocess.run(['link_purify','-imgs','{0}outim_{1}.txt'.format(sfpath, ofnames[m]),\
                        '-pairdets','{0}pairdets_{1}.csv'.format(sfpath, ofnames[m]), \
                        '-lflist','{0}{1}_lflist'.format(sfpath, ofnames[m]),\
                        '-outsum','{0}LPLsum_{1}.csv'.format(sfpath, ofnames[m]),\
                        '-clust2det','{0}LPLclust2det_{1}.csv'.format(sfpath, ofnames[m])])
# Out:
# Checking out argv[1] = -imgs.
# Checking out argv[3] = -pairdets.
# Checking out argv[5] = -lflist.
# Checking out argv[7] = -outsum.
# Checking out argv[9] = -clust2det.
# input paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_cart.csv
# input cluster list file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_cart_lflist
# Maximum RMS in km: 100000
# Maximum astrometric RMS: 1
# Maximum fraction of points to be rejected: 0.5
# Minimum number of observing nights: 3
# Minimum number of unique detections: 6
# output cluster file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_cart.csv
# output rms file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_cart.csv
# Reference MJD will be set to MJD-at-the-epoch from a previous orbit fit, if available.
# Defaulting to simplex type = 1
# Maximum fraction of points that can be rejected = 0.5, which is the default.
# Maximum number of points that can be rejected = 50, which is the default.
# Minimum number of distinct nights of observations for a discovery is 3, which is the default.
# Minimum number of unique observations for a discovery is 6, which is the default.
# Because the cluster-metric exponent for the number of unique points (which is set to -1) and/or
# the corresponding exponent for the number of unique nights (which is set to 1) is negative,
# a special (and recommended) case is triggered in which the cluster metric
# will be the product of the numbers of unique detections on every night that had some detections.
# E.g., an object observed twice per night on three nights would get a metric of 2*2*2 = 8.
# The total timespan will be raised to the power of 0,
# which is the default.
# Finally, the astrometric RMS will be raised to the power of (negative) 2,
# which is the default.
# Defaulting to maximum cluster RMS = 100000 km
# Maximum permitted astrometric residual RMS is 1 arcsec, which is the default.
# summary output file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_cart.csv
# output clust2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_cart.csv
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_cart.txt read successfully to the end.
# Read 18 data lines from image file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_cart.txt
# Read 15 data lines from paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_cart.csv
# Read 1 data lines from cluster summary file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/sum_pratchett_cart.csv
# Read 9 data lines from cluster-to-detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/clust2det_pratchett_cart.csv
# Finished creating master cluster summary vector with length 1,
# and master cluster-to-detection vector with length 9
# Launching link_purify()
# Epoch-of-orbit MJD will be used as MJDref, if available.
# Maximum RMS in km: 100000
# Because the cluster-metric exponent for the number of unique points (which is set to -1) and/or
# the corresponding exponent for the number of unique nights (which is set to 1) is negative,
# a special (and recommended) case is triggered in which the cluster metric
# will be the product of the numbers of unique detections on every night that had some detections.
# E.g., an object observed twice per night on three nights would get a metric of 2*2*2 = 8.
# The total timespan will be raised to the power of 0,
# and the astrometric RMS will be raised to the power of (negative) 2
# Duplicate-culled cluster summary vector has length 1,
# Fitting cluster 0 of 1:  astromrms = 0.0104445 arcsec, dup=0
# Writing out good cluster 0
# Finished loading input clusters: 1 out of 1 passed initial screening.
# Accepted good cluster 1 with metric 220008
# Writing 1 lines to output cluster-summary file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_cart.csv
# Writing 9 lines to output clust2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_cart.csv
# Checking out argv[1] = -imgs.
# Checking out argv[3] = -pairdets.
# Checking out argv[5] = -lflist.
# Checking out argv[7] = -outsum.
# Checking out argv[9] = -clust2det.
# input paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a1_-12.0.csv
# input cluster list file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a1_-12.0_lflist
# Maximum RMS in km: 100000
# Maximum astrometric RMS: 1
# Maximum fraction of points to be rejected: 0.5
# Minimum number of observing nights: 3
# Minimum number of unique detections: 6
# output cluster file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a1_-12.0.csv
# output rms file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a1_-12.0.csv
# Reference MJD will be set to MJD-at-the-epoch from a previous orbit fit, if available.
# Defaulting to simplex type = 1
# Maximum fraction of points that can be rejected = 0.5, which is the default.
# Maximum number of points that can be rejected = 50, which is the default.
# Minimum number of distinct nights of observations for a discovery is 3, which is the default.
# Minimum number of unique observations for a discovery is 6, which is the default.
# Because the cluster-metric exponent for the number of unique points (which is set to -1) and/or
# the corresponding exponent for the number of unique nights (which is set to 1) is negative,
# a special (and recommended) case is triggered in which the cluster metric
# will be the product of the numbers of unique detections on every night that had some detections.
# E.g., an object observed twice per night on three nights would get a metric of 2*2*2 = 8.
# The total timespan will be raised to the power of 0,
# which is the default.
# Finally, the astrometric RMS will be raised to the power of (negative) 2,
# which is the default.
# Defaulting to maximum cluster RMS = 100000 km
# Maximum permitted astrometric residual RMS is 1 arcsec, which is the default.
# summary output file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a1_-12.0.csv
# output clust2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a1_-12.0.csv
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a1_-12.0.txt read successfully to the end.
# Read 18 data lines from image file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a1_-12.0.txt
# Read 15 data lines from paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a1_-12.0.csv
# Read 1 data lines from cluster summary file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/sum_pratchett_ng_a1_-12.0.csv
# Read 9 data lines from cluster-to-detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/clust2det_pratchett_ng_a1_-12.0.csv
# Finished creating master cluster summary vector with length 1,
# and master cluster-to-detection vector with length 9
# Launching link_purify()
# Epoch-of-orbit MJD will be used as MJDref, if available.
# Maximum RMS in km: 100000
# Because the cluster-metric exponent for the number of unique points (which is set to -1) and/or
# the corresponding exponent for the number of unique nights (which is set to 1) is negative,
# a special (and recommended) case is triggered in which the cluster metric
# will be the product of the numbers of unique detections on every night that had some detections.
# E.g., an object observed twice per night on three nights would get a metric of 2*2*2 = 8.
# The total timespan will be raised to the power of 0,
# and the astrometric RMS will be raised to the power of (negative) 2
# Duplicate-culled cluster summary vector has length 1,
# Fitting cluster 0 of 1:  astromrms = 0.0103011 arcsec, dup=0
# Writing out good cluster 0
# Finished loading input clusters: 1 out of 1 passed initial screening.
# Accepted good cluster 1 with metric 226175
# Writing 1 lines to output cluster-summary file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a1_-12.0.csv
# Writing 9 lines to output clust2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a1_-12.0.csv
# Checking out argv[1] = -imgs.
# Checking out argv[3] = -pairdets.
# Checking out argv[5] = -lflist.
# Checking out argv[7] = -outsum.
# Checking out argv[9] = -clust2det.
# input paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a2_-12.0.csv
# input cluster list file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a2_-12.0_lflist
# Maximum RMS in km: 100000
# Maximum astrometric RMS: 1
# Maximum fraction of points to be rejected: 0.5
# Minimum number of observing nights: 3
# Minimum number of unique detections: 6
# output cluster file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a2_-12.0.csv
# output rms file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a2_-12.0.csv
# Reference MJD will be set to MJD-at-the-epoch from a previous orbit fit, if available.
# Defaulting to simplex type = 1
# Maximum fraction of points that can be rejected = 0.5, which is the default.
# Maximum number of points that can be rejected = 50, which is the default.
# Minimum number of distinct nights of observations for a discovery is 3, which is the default.
# Minimum number of unique observations for a discovery is 6, which is the default.
# Because the cluster-metric exponent for the number of unique points (which is set to -1) and/or
# the corresponding exponent for the number of unique nights (which is set to 1) is negative,
# a special (and recommended) case is triggered in which the cluster metric
# will be the product of the numbers of unique detections on every night that had some detections.
# E.g., an object observed twice per night on three nights would get a metric of 2*2*2 = 8.
# The total timespan will be raised to the power of 0,
# which is the default.
# Finally, the astrometric RMS will be raised to the power of (negative) 2,
# which is the default.
# Defaulting to maximum cluster RMS = 100000 km
# Maximum permitted astrometric residual RMS is 1 arcsec, which is the default.
# summary output file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a2_-12.0.csv
# output clust2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a2_-12.0.csv
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a2_-12.0.txt read successfully to the end.
# Read 18 data lines from image file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a2_-12.0.txt
# Read 15 data lines from paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a2_-12.0.csv
# Read 1 data lines from cluster summary file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/sum_pratchett_ng_a2_-12.0.csv
# Read 9 data lines from cluster-to-detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/clust2det_pratchett_ng_a2_-12.0.csv
# Finished creating master cluster summary vector with length 1,
# and master cluster-to-detection vector with length 9
# Launching link_purify()
# Epoch-of-orbit MJD will be used as MJDref, if available.
# Maximum RMS in km: 100000
# Because the cluster-metric exponent for the number of unique points (which is set to -1) and/or
# the corresponding exponent for the number of unique nights (which is set to 1) is negative,
# a special (and recommended) case is triggered in which the cluster metric
# will be the product of the numbers of unique detections on every night that had some detections.
# E.g., an object observed twice per night on three nights would get a metric of 2*2*2 = 8.
# The total timespan will be raised to the power of 0,
# and the astrometric RMS will be raised to the power of (negative) 2
# Duplicate-culled cluster summary vector has length 1,
# Fitting cluster 0 of 1:  astromrms = 0.0197431 arcsec, dup=0
# Writing out good cluster 0
# Finished loading input clusters: 1 out of 1 passed initial screening.
# Accepted good cluster 1 with metric 61571.4
# Writing 1 lines to output cluster-summary file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a2_-12.0.csv
# Writing 9 lines to output clust2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a2_-12.0.csv
# Checking out argv[1] = -imgs.
# Checking out argv[3] = -pairdets.
# Checking out argv[5] = -lflist.
# Checking out argv[7] = -outsum.
# Checking out argv[9] = -clust2det.
# input paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a3_-12.0.csv
# input cluster list file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a3_-12.0_lflist
# Maximum RMS in km: 100000
# Maximum astrometric RMS: 1
# Maximum fraction of points to be rejected: 0.5
# Minimum number of observing nights: 3
# Minimum number of unique detections: 6
# output cluster file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a3_-12.0.csv
# output rms file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a3_-12.0.csv
# Reference MJD will be set to MJD-at-the-epoch from a previous orbit fit, if available.
# Defaulting to simplex type = 1
# Maximum fraction of points that can be rejected = 0.5, which is the default.
# Maximum number of points that can be rejected = 50, which is the default.
# Minimum number of distinct nights of observations for a discovery is 3, which is the default.
# Minimum number of unique observations for a discovery is 6, which is the default.
# Because the cluster-metric exponent for the number of unique points (which is set to -1) and/or
# the corresponding exponent for the number of unique nights (which is set to 1) is negative,
# a special (and recommended) case is triggered in which the cluster metric
# will be the product of the numbers of unique detections on every night that had some detections.
# E.g., an object observed twice per night on three nights would get a metric of 2*2*2 = 8.
# The total timespan will be raised to the power of 0,
# which is the default.
# Finally, the astrometric RMS will be raised to the power of (negative) 2,
# which is the default.
# Defaulting to maximum cluster RMS = 100000 km
# Maximum permitted astrometric residual RMS is 1 arcsec, which is the default.
# summary output file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a3_-12.0.csv
# output clust2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a3_-12.0.csv
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a3_-12.0.txt read successfully to the end.
# Read 18 data lines from image file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a3_-12.0.txt
# Read 15 data lines from paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a3_-12.0.csv
# Read 1 data lines from cluster summary file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/sum_pratchett_ng_a3_-12.0.csv
# Read 9 data lines from cluster-to-detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/clust2det_pratchett_ng_a3_-12.0.csv
# Finished creating master cluster summary vector with length 1,
# and master cluster-to-detection vector with length 9
# Launching link_purify()
# Epoch-of-orbit MJD will be used as MJDref, if available.
# Maximum RMS in km: 100000
# Because the cluster-metric exponent for the number of unique points (which is set to -1) and/or
# the corresponding exponent for the number of unique nights (which is set to 1) is negative,
# a special (and recommended) case is triggered in which the cluster metric
# will be the product of the numbers of unique detections on every night that had some detections.
# E.g., an object observed twice per night on three nights would get a metric of 2*2*2 = 8.
# The total timespan will be raised to the power of 0,
# and the astrometric RMS will be raised to the power of (negative) 2
# Duplicate-culled cluster summary vector has length 1,
# Fitting cluster 0 of 1:  astromrms = 0.0132832 arcsec, dup=0
# Writing out good cluster 0
# Finished loading input clusters: 1 out of 1 passed initial screening.
# Accepted good cluster 1 with metric 136021
# Writing 1 lines to output cluster-summary file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a3_-12.0.csv
# Writing 9 lines to output clust2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a3_-12.0.csv
# Checking out argv[1] = -imgs.
# Checking out argv[3] = -pairdets.
# Checking out argv[5] = -lflist.
# Checking out argv[7] = -outsum.
# Checking out argv[9] = -clust2det.
# input paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a1_-11.0.csv
# input cluster list file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a1_-11.0_lflist
# Maximum RMS in km: 100000
# Maximum astrometric RMS: 1
# Maximum fraction of points to be rejected: 0.5
# Minimum number of observing nights: 3
# Minimum number of unique detections: 6
# output cluster file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a1_-11.0.csv
# output rms file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a1_-11.0.csv
# Reference MJD will be set to MJD-at-the-epoch from a previous orbit fit, if available.
# Defaulting to simplex type = 1
# Maximum fraction of points that can be rejected = 0.5, which is the default.
# Maximum number of points that can be rejected = 50, which is the default.
# Minimum number of distinct nights of observations for a discovery is 3, which is the default.
# Minimum number of unique observations for a discovery is 6, which is the default.
# Because the cluster-metric exponent for the number of unique points (which is set to -1) and/or
# the corresponding exponent for the number of unique nights (which is set to 1) is negative,
# a special (and recommended) case is triggered in which the cluster metric
# will be the product of the numbers of unique detections on every night that had some detections.
# E.g., an object observed twice per night on three nights would get a metric of 2*2*2 = 8.
# The total timespan will be raised to the power of 0,
# which is the default.
# Finally, the astrometric RMS will be raised to the power of (negative) 2,
# which is the default.
# Defaulting to maximum cluster RMS = 100000 km
# Maximum permitted astrometric residual RMS is 1 arcsec, which is the default.
# summary output file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a1_-11.0.csv
# output clust2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a1_-11.0.csv
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a1_-11.0.txt read successfully to the end.
# Read 18 data lines from image file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a1_-11.0.txt
# Read 15 data lines from paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a1_-11.0.csv
# Read 1 data lines from cluster summary file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/sum_pratchett_ng_a1_-11.0.csv
# Read 9 data lines from cluster-to-detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/clust2det_pratchett_ng_a1_-11.0.csv
# Finished creating master cluster summary vector with length 1,
# and master cluster-to-detection vector with length 9
# Launching link_purify()
# Epoch-of-orbit MJD will be used as MJDref, if available.
# Maximum RMS in km: 100000
# Because the cluster-metric exponent for the number of unique points (which is set to -1) and/or
# the corresponding exponent for the number of unique nights (which is set to 1) is negative,
# a special (and recommended) case is triggered in which the cluster metric
# will be the product of the numbers of unique detections on every night that had some detections.
# E.g., an object observed twice per night on three nights would get a metric of 2*2*2 = 8.
# The total timespan will be raised to the power of 0,
# and the astrometric RMS will be raised to the power of (negative) 2
# Duplicate-culled cluster summary vector has length 1,
# Fitting cluster 0 of 1:  astromrms = 0.0151799 arcsec, dup=0
# Writing out good cluster 0
# Finished loading input clusters: 1 out of 1 passed initial screening.
# Accepted good cluster 1 with metric 104153
# Writing 1 lines to output cluster-summary file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a1_-11.0.csv
# Writing 9 lines to output clust2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a1_-11.0.csv
# Checking out argv[1] = -imgs.
# Checking out argv[3] = -pairdets.
# Checking out argv[5] = -lflist.
# Checking out argv[7] = -outsum.
# Checking out argv[9] = -clust2det.
# input paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a2_-11.0.csv
# input cluster list file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a2_-11.0_lflist
# Maximum RMS in km: 100000
# Maximum astrometric RMS: 1
# Maximum fraction of points to be rejected: 0.5
# Minimum number of observing nights: 3
# Minimum number of unique detections: 6
# output cluster file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a2_-11.0.csv
# output rms file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a2_-11.0.csv
# Reference MJD will be set to MJD-at-the-epoch from a previous orbit fit, if available.
# Defaulting to simplex type = 1
# Maximum fraction of points that can be rejected = 0.5, which is the default.
# Maximum number of points that can be rejected = 50, which is the default.
# Minimum number of distinct nights of observations for a discovery is 3, which is the default.
# Minimum number of unique observations for a discovery is 6, which is the default.
# Because the cluster-metric exponent for the number of unique points (which is set to -1) and/or
# the corresponding exponent for the number of unique nights (which is set to 1) is negative,
# a special (and recommended) case is triggered in which the cluster metric
# will be the product of the numbers of unique detections on every night that had some detections.
# E.g., an object observed twice per night on three nights would get a metric of 2*2*2 = 8.
# The total timespan will be raised to the power of 0,
# which is the default.
# Finally, the astrometric RMS will be raised to the power of (negative) 2,
# which is the default.
# Defaulting to maximum cluster RMS = 100000 km
# Maximum permitted astrometric residual RMS is 1 arcsec, which is the default.
# summary output file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a2_-11.0.csv
# output clust2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a2_-11.0.csv
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a2_-11.0.txt read successfully to the end.
# Read 18 data lines from image file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a2_-11.0.txt
# Read 15 data lines from paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a2_-11.0.csv
# Read 1 data lines from cluster summary file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/sum_pratchett_ng_a2_-11.0.csv
# Read 9 data lines from cluster-to-detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/clust2det_pratchett_ng_a2_-11.0.csv
# Finished creating master cluster summary vector with length 1,
# and master cluster-to-detection vector with length 9
# Launching link_purify()
# Epoch-of-orbit MJD will be used as MJDref, if available.
# Maximum RMS in km: 100000
# Because the cluster-metric exponent for the number of unique points (which is set to -1) and/or
# the corresponding exponent for the number of unique nights (which is set to 1) is negative,
# a special (and recommended) case is triggered in which the cluster metric
# will be the product of the numbers of unique detections on every night that had some detections.
# E.g., an object observed twice per night on three nights would get a metric of 2*2*2 = 8.
# The total timespan will be raised to the power of 0,
# and the astrometric RMS will be raised to the power of (negative) 2
# Duplicate-culled cluster summary vector has length 1,
# Fitting cluster 0 of 1:  astromrms = 0.0134303 arcsec, dup=0
# Writing out good cluster 0
# Finished loading input clusters: 1 out of 1 passed initial screening.
# Accepted good cluster 1 with metric 133057
# Writing 1 lines to output cluster-summary file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a2_-11.0.csv
# Writing 9 lines to output clust2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a2_-11.0.csv
# Checking out argv[1] = -imgs.
# Checking out argv[3] = -pairdets.
# Checking out argv[5] = -lflist.
# Checking out argv[7] = -outsum.
# Checking out argv[9] = -clust2det.
# input paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a3_-11.0.csv
# input cluster list file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a3_-11.0_lflist
# Maximum RMS in km: 100000
# Maximum astrometric RMS: 1
# Maximum fraction of points to be rejected: 0.5
# Minimum number of observing nights: 3
# Minimum number of unique detections: 6
# output cluster file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a3_-11.0.csv
# output rms file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a3_-11.0.csv
# Reference MJD will be set to MJD-at-the-epoch from a previous orbit fit, if available.
# Defaulting to simplex type = 1
# Maximum fraction of points that can be rejected = 0.5, which is the default.
# Maximum number of points that can be rejected = 50, which is the default.
# Minimum number of distinct nights of observations for a discovery is 3, which is the default.
# Minimum number of unique observations for a discovery is 6, which is the default.
# Because the cluster-metric exponent for the number of unique points (which is set to -1) and/or
# the corresponding exponent for the number of unique nights (which is set to 1) is negative,
# a special (and recommended) case is triggered in which the cluster metric
# will be the product of the numbers of unique detections on every night that had some detections.
# E.g., an object observed twice per night on three nights would get a metric of 2*2*2 = 8.
# The total timespan will be raised to the power of 0,
# which is the default.
# Finally, the astrometric RMS will be raised to the power of (negative) 2,
# which is the default.
# Defaulting to maximum cluster RMS = 100000 km
# Maximum permitted astrometric residual RMS is 1 arcsec, which is the default.
# summary output file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a3_-11.0.csv
# output clust2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a3_-11.0.csv
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a3_-11.0.txt read successfully to the end.
# Read 18 data lines from image file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a3_-11.0.txt
# Read 15 data lines from paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a3_-11.0.csv
# Read 1 data lines from cluster summary file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/sum_pratchett_ng_a3_-11.0.csv
# Read 9 data lines from cluster-to-detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/clust2det_pratchett_ng_a3_-11.0.csv
# Finished creating master cluster summary vector with length 1,
# and master cluster-to-detection vector with length 9
# Launching link_purify()
# Epoch-of-orbit MJD will be used as MJDref, if available.
# Maximum RMS in km: 100000
# Because the cluster-metric exponent for the number of unique points (which is set to -1) and/or
# the corresponding exponent for the number of unique nights (which is set to 1) is negative,
# a special (and recommended) case is triggered in which the cluster metric
# will be the product of the numbers of unique detections on every night that had some detections.
# E.g., an object observed twice per night on three nights would get a metric of 2*2*2 = 8.
# The total timespan will be raised to the power of 0,
# and the astrometric RMS will be raised to the power of (negative) 2
# Duplicate-culled cluster summary vector has length 1,
# Fitting cluster 0 of 1:  astromrms = 0.0186271 arcsec, dup=0
# Writing out good cluster 0
# Finished loading input clusters: 1 out of 1 passed initial screening.
# Accepted good cluster 1 with metric 69170.5
# Writing 1 lines to output cluster-summary file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a3_-11.0.csv
# Writing 9 lines to output clust2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a3_-11.0.csv
# Checking out argv[1] = -imgs.
# Checking out argv[3] = -pairdets.
# Checking out argv[5] = -lflist.
# Checking out argv[7] = -outsum.
# Checking out argv[9] = -clust2det.
# input paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a1_-10.0.csv
# input cluster list file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a1_-10.0_lflist
# Maximum RMS in km: 100000
# Maximum astrometric RMS: 1
# Maximum fraction of points to be rejected: 0.5
# Minimum number of observing nights: 3
# Minimum number of unique detections: 6
# output cluster file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a1_-10.0.csv
# output rms file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a1_-10.0.csv
# Reference MJD will be set to MJD-at-the-epoch from a previous orbit fit, if available.
# Defaulting to simplex type = 1
# Maximum fraction of points that can be rejected = 0.5, which is the default.
# Maximum number of points that can be rejected = 50, which is the default.
# Minimum number of distinct nights of observations for a discovery is 3, which is the default.
# Minimum number of unique observations for a discovery is 6, which is the default.
# Because the cluster-metric exponent for the number of unique points (which is set to -1) and/or
# the corresponding exponent for the number of unique nights (which is set to 1) is negative,
# a special (and recommended) case is triggered in which the cluster metric
# will be the product of the numbers of unique detections on every night that had some detections.
# E.g., an object observed twice per night on three nights would get a metric of 2*2*2 = 8.
# The total timespan will be raised to the power of 0,
# which is the default.
# Finally, the astrometric RMS will be raised to the power of (negative) 2,
# which is the default.
# Defaulting to maximum cluster RMS = 100000 km
# Maximum permitted astrometric residual RMS is 1 arcsec, which is the default.
# summary output file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a1_-10.0.csv
# output clust2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a1_-10.0.csv
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a1_-10.0.txt read successfully to the end.
# Read 18 data lines from image file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a1_-10.0.txt
# Read 15 data lines from paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a1_-10.0.csv
# Read 1 data lines from cluster summary file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/sum_pratchett_ng_a1_-10.0.csv
# Read 9 data lines from cluster-to-detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/clust2det_pratchett_ng_a1_-10.0.csv
# Finished creating master cluster summary vector with length 1,
# and master cluster-to-detection vector with length 9
# Launching link_purify()
# Epoch-of-orbit MJD will be used as MJDref, if available.
# Maximum RMS in km: 100000
# Because the cluster-metric exponent for the number of unique points (which is set to -1) and/or
# the corresponding exponent for the number of unique nights (which is set to 1) is negative,
# a special (and recommended) case is triggered in which the cluster metric
# will be the product of the numbers of unique detections on every night that had some detections.
# E.g., an object observed twice per night on three nights would get a metric of 2*2*2 = 8.
# The total timespan will be raised to the power of 0,
# and the astrometric RMS will be raised to the power of (negative) 2
# Duplicate-culled cluster summary vector has length 1,
# Fitting cluster 0 of 1:  astromrms = 0.0108154 arcsec, dup=0
# Writing out good cluster 0
# Finished loading input clusters: 1 out of 1 passed initial screening.
# Accepted good cluster 1 with metric 205174
# Writing 1 lines to output cluster-summary file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a1_-10.0.csv
# Writing 9 lines to output clust2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a1_-10.0.csv
# Checking out argv[1] = -imgs.
# Checking out argv[3] = -pairdets.
# Checking out argv[5] = -lflist.
# Checking out argv[7] = -outsum.
# Checking out argv[9] = -clust2det.
# input paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a2_-10.0.csv
# input cluster list file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a2_-10.0_lflist
# Maximum RMS in km: 100000
# Maximum astrometric RMS: 1
# Maximum fraction of points to be rejected: 0.5
# Minimum number of observing nights: 3
# Minimum number of unique detections: 6
# output cluster file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a2_-10.0.csv
# output rms file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a2_-10.0.csv
# Reference MJD will be set to MJD-at-the-epoch from a previous orbit fit, if available.
# Defaulting to simplex type = 1
# Maximum fraction of points that can be rejected = 0.5, which is the default.
# Maximum number of points that can be rejected = 50, which is the default.
# Minimum number of distinct nights of observations for a discovery is 3, which is the default.
# Minimum number of unique observations for a discovery is 6, which is the default.
# Because the cluster-metric exponent for the number of unique points (which is set to -1) and/or
# the corresponding exponent for the number of unique nights (which is set to 1) is negative,
# a special (and recommended) case is triggered in which the cluster metric
# will be the product of the numbers of unique detections on every night that had some detections.
# E.g., an object observed twice per night on three nights would get a metric of 2*2*2 = 8.
# The total timespan will be raised to the power of 0,
# which is the default.
# Finally, the astrometric RMS will be raised to the power of (negative) 2,
# which is the default.
# Defaulting to maximum cluster RMS = 100000 km
# Maximum permitted astrometric residual RMS is 1 arcsec, which is the default.
# summary output file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a2_-10.0.csv
# output clust2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a2_-10.0.csv
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a2_-10.0.txt read successfully to the end.
# Read 18 data lines from image file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a2_-10.0.txt
# Read 15 data lines from paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a2_-10.0.csv
# Read 1 data lines from cluster summary file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/sum_pratchett_ng_a2_-10.0.csv
# Read 9 data lines from cluster-to-detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/clust2det_pratchett_ng_a2_-10.0.csv
# Finished creating master cluster summary vector with length 1,
# and master cluster-to-detection vector with length 9
# Launching link_purify()
# Epoch-of-orbit MJD will be used as MJDref, if available.
# Maximum RMS in km: 100000
# Because the cluster-metric exponent for the number of unique points (which is set to -1) and/or
# the corresponding exponent for the number of unique nights (which is set to 1) is negative,
# a special (and recommended) case is triggered in which the cluster metric
# will be the product of the numbers of unique detections on every night that had some detections.
# E.g., an object observed twice per night on three nights would get a metric of 2*2*2 = 8.
# The total timespan will be raised to the power of 0,
# and the astrometric RMS will be raised to the power of (negative) 2
# Duplicate-culled cluster summary vector has length 1,
# Fitting cluster 0 of 1:  astromrms = 0.0186101 arcsec, dup=0
# Writing out good cluster 0
# Finished loading input clusters: 1 out of 1 passed initial screening.
# Accepted good cluster 1 with metric 69296.9
# Writing 1 lines to output cluster-summary file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a2_-10.0.csv
# Writing 9 lines to output clust2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a2_-10.0.csv
# Checking out argv[1] = -imgs.
# Checking out argv[3] = -pairdets.
# Checking out argv[5] = -lflist.
# Checking out argv[7] = -outsum.
# Checking out argv[9] = -clust2det.
# input paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a3_-10.0.csv
# input cluster list file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a3_-10.0_lflist
# Maximum RMS in km: 100000
# Maximum astrometric RMS: 1
# Maximum fraction of points to be rejected: 0.5
# Minimum number of observing nights: 3
# Minimum number of unique detections: 6
# output cluster file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a3_-10.0.csv
# output rms file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a3_-10.0.csv
# Reference MJD will be set to MJD-at-the-epoch from a previous orbit fit, if available.
# Defaulting to simplex type = 1
# Maximum fraction of points that can be rejected = 0.5, which is the default.
# Maximum number of points that can be rejected = 50, which is the default.
# Minimum number of distinct nights of observations for a discovery is 3, which is the default.
# Minimum number of unique observations for a discovery is 6, which is the default.
# Because the cluster-metric exponent for the number of unique points (which is set to -1) and/or
# the corresponding exponent for the number of unique nights (which is set to 1) is negative,
# a special (and recommended) case is triggered in which the cluster metric
# will be the product of the numbers of unique detections on every night that had some detections.
# E.g., an object observed twice per night on three nights would get a metric of 2*2*2 = 8.
# The total timespan will be raised to the power of 0,
# which is the default.
# Finally, the astrometric RMS will be raised to the power of (negative) 2,
# which is the default.
# Defaulting to maximum cluster RMS = 100000 km
# Maximum permitted astrometric residual RMS is 1 arcsec, which is the default.
# summary output file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a3_-10.0.csv
# output clust2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a3_-10.0.csv
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a3_-10.0.txt read successfully to the end.
# Read 18 data lines from image file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a3_-10.0.txt
# Read 15 data lines from paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a3_-10.0.csv
# Read 1 data lines from cluster summary file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/sum_pratchett_ng_a3_-10.0.csv
# Read 9 data lines from cluster-to-detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/clust2det_pratchett_ng_a3_-10.0.csv
# Finished creating master cluster summary vector with length 1,
# and master cluster-to-detection vector with length 9
# Launching link_purify()
# Epoch-of-orbit MJD will be used as MJDref, if available.
# Maximum RMS in km: 100000
# Because the cluster-metric exponent for the number of unique points (which is set to -1) and/or
# the corresponding exponent for the number of unique nights (which is set to 1) is negative,
# a special (and recommended) case is triggered in which the cluster metric
# will be the product of the numbers of unique detections on every night that had some detections.
# E.g., an object observed twice per night on three nights would get a metric of 2*2*2 = 8.
# The total timespan will be raised to the power of 0,
# and the astrometric RMS will be raised to the power of (negative) 2
# Duplicate-culled cluster summary vector has length 1,
# Fitting cluster 0 of 1:  astromrms = 0.0125761 arcsec, dup=0
# Writing out good cluster 0
# Finished loading input clusters: 1 out of 1 passed initial screening.
# Accepted good cluster 1 with metric 151746
# Writing 1 lines to output cluster-summary file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a3_-10.0.csv
# Writing 9 lines to output clust2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a3_-10.0.csv
# Checking out argv[1] = -imgs.
# Checking out argv[3] = -pairdets.
# Checking out argv[5] = -lflist.
# Checking out argv[7] = -outsum.
# Checking out argv[9] = -clust2det.
# input paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a1_-9.0.csv
# input cluster list file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a1_-9.0_lflist
# Maximum RMS in km: 100000
# Maximum astrometric RMS: 1
# Maximum fraction of points to be rejected: 0.5
# Minimum number of observing nights: 3
# Minimum number of unique detections: 6
# output cluster file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a1_-9.0.csv
# output rms file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a1_-9.0.csv
# Reference MJD will be set to MJD-at-the-epoch from a previous orbit fit, if available.
# Defaulting to simplex type = 1
# Maximum fraction of points that can be rejected = 0.5, which is the default.
# Maximum number of points that can be rejected = 50, which is the default.
# Minimum number of distinct nights of observations for a discovery is 3, which is the default.
# Minimum number of unique observations for a discovery is 6, which is the default.
# Because the cluster-metric exponent for the number of unique points (which is set to -1) and/or
# the corresponding exponent for the number of unique nights (which is set to 1) is negative,
# a special (and recommended) case is triggered in which the cluster metric
# will be the product of the numbers of unique detections on every night that had some detections.
# E.g., an object observed twice per night on three nights would get a metric of 2*2*2 = 8.
# The total timespan will be raised to the power of 0,
# which is the default.
# Finally, the astrometric RMS will be raised to the power of (negative) 2,
# which is the default.
# Defaulting to maximum cluster RMS = 100000 km
# Maximum permitted astrometric residual RMS is 1 arcsec, which is the default.
# summary output file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a1_-9.0.csv
# output clust2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a1_-9.0.csv
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a1_-9.0.txt read successfully to the end.
# Read 18 data lines from image file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a1_-9.0.txt
# Read 15 data lines from paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a1_-9.0.csv
# Read 1 data lines from cluster summary file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/sum_pratchett_ng_a1_-9.0.csv
# Read 9 data lines from cluster-to-detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/clust2det_pratchett_ng_a1_-9.0.csv
# Finished creating master cluster summary vector with length 1,
# and master cluster-to-detection vector with length 9
# Launching link_purify()
# Epoch-of-orbit MJD will be used as MJDref, if available.
# Maximum RMS in km: 100000
# Because the cluster-metric exponent for the number of unique points (which is set to -1) and/or
# the corresponding exponent for the number of unique nights (which is set to 1) is negative,
# a special (and recommended) case is triggered in which the cluster metric
# will be the product of the numbers of unique detections on every night that had some detections.
# E.g., an object observed twice per night on three nights would get a metric of 2*2*2 = 8.
# The total timespan will be raised to the power of 0,
# and the astrometric RMS will be raised to the power of (negative) 2
# Duplicate-culled cluster summary vector has length 1,
# Fitting cluster 0 of 1:  astromrms = 0.0131795 arcsec, dup=0
# Writing out good cluster 0
# Finished loading input clusters: 1 out of 1 passed initial screening.
# Accepted good cluster 1 with metric 138170
# Writing 1 lines to output cluster-summary file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a1_-9.0.csv
# Writing 9 lines to output clust2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a1_-9.0.csv
# Checking out argv[1] = -imgs.
# Checking out argv[3] = -pairdets.
# Checking out argv[5] = -lflist.
# Checking out argv[7] = -outsum.
# Checking out argv[9] = -clust2det.
# input paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a2_-9.0.csv
# input cluster list file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a2_-9.0_lflist
# Maximum RMS in km: 100000
# Maximum astrometric RMS: 1
# Maximum fraction of points to be rejected: 0.5
# Minimum number of observing nights: 3
# Minimum number of unique detections: 6
# output cluster file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a2_-9.0.csv
# output rms file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a2_-9.0.csv
# Reference MJD will be set to MJD-at-the-epoch from a previous orbit fit, if available.
# Defaulting to simplex type = 1
# Maximum fraction of points that can be rejected = 0.5, which is the default.
# Maximum number of points that can be rejected = 50, which is the default.
# Minimum number of distinct nights of observations for a discovery is 3, which is the default.
# Minimum number of unique observations for a discovery is 6, which is the default.
# Because the cluster-metric exponent for the number of unique points (which is set to -1) and/or
# the corresponding exponent for the number of unique nights (which is set to 1) is negative,
# a special (and recommended) case is triggered in which the cluster metric
# ...
# Maximum RMS in km: 100000
# Maximum astrometric RMS: 1
# Maximum fraction of points to be rejected: 0.5
# Minimum number of observing nights: 3
# Minimum number of unique detections: 6
# output cluster file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a3_1.0.csv
# output rms file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a3_1.0.csv
# Reference MJD will be set to MJD-at-the-epoch from a previous orbit fit, if available.
# Defaulting to simplex type = 1
# Maximum fraction of points that can be rejected = 0.5, which is the default.
# Maximum number of points that can be rejected = 50, which is the default.
# Minimum number of distinct nights of observations for a discovery is 3, which is the default.
# Minimum number of unique observations for a discovery is 6, which is the default.
# Because the cluster-metric exponent for the number of unique points (which is set to -1) and/or
# the corresponding exponent for the number of unique nights (which is set to 1) is negative,
# a special (and recommended) case is triggered in which the cluster metric
# will be the product of the numbers of unique detections on every night that had some detections.
# E.g., an object observed twice per night on three nights would get a metric of 2*2*2 = 8.
# The total timespan will be raised to the power of 0,
# which is the default.
# Finally, the astrometric RMS will be raised to the power of (negative) 2,
# which is the default.
# Defaulting to maximum cluster RMS = 100000 km
# Maximum permitted astrometric residual RMS is 1 arcsec, which is the default.
# summary output file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a3_1.0.csv
# output clust2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a3_1.0.csv
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a3_1.0.txt read successfully to the end.
# Read 15 data lines from image file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a3_1.0.txt
# Read 14 data lines from paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a3_1.0.csv
# Read 0 data lines from cluster summary file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/sum_pratchett_ng_a3_1.0.csv
# Read 0 data lines from cluster-to-detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/clust2det_pratchett_ng_a3_1.0.csv
# Finished creating master cluster summary vector with length 0,
# and master cluster-to-detection vector with length 0
# Launching link_purify()
# Epoch-of-orbit MJD will be used as MJDref, if available.
# Maximum RMS in km: 100000
# Because the cluster-metric exponent for the number of unique points (which is set to -1) and/or
# the corresponding exponent for the number of unique nights (which is set to 1) is negative,
# a special (and recommended) case is triggered in which the cluster metric
# will be the product of the numbers of unique detections on every night that had some detections.
# E.g., an object observed twice per night on three nights would get a metric of 2*2*2 = 8.
# The total timespan will be raised to the power of 0,
# and the astrometric RMS will be raised to the power of (negative) 2
# Duplicate-culled cluster summary vector has length 0,
# Finished loading input clusters: 0 out of 0 passed initial screening.
# Writing 0 lines to output cluster-summary file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a3_1.0.csv
# Writing 0 lines to output clust2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a3_1.0.csv
# Checking out argv[1] = -imgs.
# Checking out argv[3] = -pairdets.
# Checking out argv[5] = -lflist.
# Checking out argv[7] = -outsum.
# Checking out argv[9] = -clust2det.
# input paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a2_2.0.csv
# input cluster list file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a2_2.0_lflist
# Maximum RMS in km: 100000
# Maximum astrometric RMS: 1
# Maximum fraction of points to be rejected: 0.5
# Minimum number of observing nights: 3
# Minimum number of unique detections: 6
# output cluster file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a2_2.0.csv
# output rms file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a2_2.0.csv
# Reference MJD will be set to MJD-at-the-epoch from a previous orbit fit, if available.
# Defaulting to simplex type = 1
# Maximum fraction of points that can be rejected = 0.5, which is the default.
# Maximum number of points that can be rejected = 50, which is the default.
# Minimum number of distinct nights of observations for a discovery is 3, which is the default.
# Minimum number of unique observations for a discovery is 6, which is the default.
# Because the cluster-metric exponent for the number of unique points (which is set to -1) and/or
# the corresponding exponent for the number of unique nights (which is set to 1) is negative,
# a special (and recommended) case is triggered in which the cluster metric
# will be the product of the numbers of unique detections on every night that had some detections.
# E.g., an object observed twice per night on three nights would get a metric of 2*2*2 = 8.
# The total timespan will be raised to the power of 0,
# which is the default.
# Finally, the astrometric RMS will be raised to the power of (negative) 2,
# which is the default.
# Defaulting to maximum cluster RMS = 100000 km
# Maximum permitted astrometric residual RMS is 1 arcsec, which is the default.
# summary output file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a2_2.0.csv
# output clust2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a2_2.0.csv
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a2_2.0.txt read successfully to the end.
# Read 12 data lines from image file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a2_2.0.txt
# Read 3 data lines from paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a2_2.0.csv
# Read 0 data lines from cluster summary file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/sum_pratchett_ng_a2_2.0.csv
# Read 0 data lines from cluster-to-detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/clust2det_pratchett_ng_a2_2.0.csv
# Finished creating master cluster summary vector with length 0,
# and master cluster-to-detection vector with length 0
# Launching link_purify()
# Epoch-of-orbit MJD will be used as MJDref, if available.
# Maximum RMS in km: 100000
# Because the cluster-metric exponent for the number of unique points (which is set to -1) and/or
# the corresponding exponent for the number of unique nights (which is set to 1) is negative,
# a special (and recommended) case is triggered in which the cluster metric
# will be the product of the numbers of unique detections on every night that had some detections.
# E.g., an object observed twice per night on three nights would get a metric of 2*2*2 = 8.
# The total timespan will be raised to the power of 0,
# and the astrometric RMS will be raised to the power of (negative) 2
# Duplicate-culled cluster summary vector has length 0,
# Finished loading input clusters: 0 out of 0 passed initial screening.
# Writing 0 lines to output cluster-summary file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a2_2.0.csv
# Writing 0 lines to output clust2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a2_2.0.csv
# Checking out argv[1] = -imgs.
# Checking out argv[3] = -pairdets.
# Checking out argv[5] = -lflist.
# Checking out argv[7] = -outsum.
# Checking out argv[9] = -clust2det.
# input paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a3_2.0.csv
# input cluster list file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a3_2.0_lflist
# Maximum RMS in km: 100000
# Maximum astrometric RMS: 1
# Maximum fraction of points to be rejected: 0.5
# Minimum number of observing nights: 3
# Minimum number of unique detections: 6
# output cluster file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a3_2.0.csv
# output rms file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a3_2.0.csv
# Reference MJD will be set to MJD-at-the-epoch from a previous orbit fit, if available.
# Defaulting to simplex type = 1
# Maximum fraction of points that can be rejected = 0.5, which is the default.
# Maximum number of points that can be rejected = 50, which is the default.
# Minimum number of distinct nights of observations for a discovery is 3, which is the default.
# Minimum number of unique observations for a discovery is 6, which is the default.
# Because the cluster-metric exponent for the number of unique points (which is set to -1) and/or
# the corresponding exponent for the number of unique nights (which is set to 1) is negative,
# a special (and recommended) case is triggered in which the cluster metric
# will be the product of the numbers of unique detections on every night that had some detections.
# E.g., an object observed twice per night on three nights would get a metric of 2*2*2 = 8.
# The total timespan will be raised to the power of 0,
# which is the default.
# Finally, the astrometric RMS will be raised to the power of (negative) 2,
# which is the default.
# Defaulting to maximum cluster RMS = 100000 km
# Maximum permitted astrometric residual RMS is 1 arcsec, which is the default.
# summary output file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a3_2.0.csv
# output clust2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a3_2.0.csv
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a3_2.0.txt read successfully to the end.
# Read 15 data lines from image file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a3_2.0.txt
# Read 14 data lines from paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a3_2.0.csv
# Read 0 data lines from cluster summary file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/sum_pratchett_ng_a3_2.0.csv
# Read 0 data lines from cluster-to-detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/clust2det_pratchett_ng_a3_2.0.csv
# Finished creating master cluster summary vector with length 0,
# and master cluster-to-detection vector with length 0
# Launching link_purify()
# Epoch-of-orbit MJD will be used as MJDref, if available.
# Maximum RMS in km: 100000
# Because the cluster-metric exponent for the number of unique points (which is set to -1) and/or
# the corresponding exponent for the number of unique nights (which is set to 1) is negative,
# a special (and recommended) case is triggered in which the cluster metric
# will be the product of the numbers of unique detections on every night that had some detections.
# E.g., an object observed twice per night on three nights would get a metric of 2*2*2 = 8.
# The total timespan will be raised to the power of 0,
# and the astrometric RMS will be raised to the power of (negative) 2
# Duplicate-culled cluster summary vector has length 0,
# Finished loading input clusters: 0 out of 0 passed initial screening.
# Writing 0 lines to output cluster-summary file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a3_2.0.csv
# Writing 0 lines to output clust2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a3_2.0.csv
# Checking out argv[1] = -imgs.
# Checking out argv[3] = -pairdets.
# Checking out argv[5] = -lflist.
# Checking out argv[7] = -outsum.
# Checking out argv[9] = -clust2det.
# input paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a3_3.0.csv
# input cluster list file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pratchett_ng_a3_3.0_lflist
# Maximum RMS in km: 100000
# Maximum astrometric RMS: 1
# Maximum fraction of points to be rejected: 0.5
# Minimum number of observing nights: 3
# Minimum number of unique detections: 6
# output cluster file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a3_3.0.csv
# output rms file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a3_3.0.csv
# Reference MJD will be set to MJD-at-the-epoch from a previous orbit fit, if available.
# Defaulting to simplex type = 1
# Maximum fraction of points that can be rejected = 0.5, which is the default.
# Maximum number of points that can be rejected = 50, which is the default.
# Minimum number of distinct nights of observations for a discovery is 3, which is the default.
# Minimum number of unique observations for a discovery is 6, which is the default.
# Because the cluster-metric exponent for the number of unique points (which is set to -1) and/or
# the corresponding exponent for the number of unique nights (which is set to 1) is negative,
# a special (and recommended) case is triggered in which the cluster metric
# will be the product of the numbers of unique detections on every night that had some detections.
# E.g., an object observed twice per night on three nights would get a metric of 2*2*2 = 8.
# The total timespan will be raised to the power of 0,
# which is the default.
# Finally, the astrometric RMS will be raised to the power of (negative) 2,
# which is the default.
# Defaulting to maximum cluster RMS = 100000 km
# Maximum permitted astrometric residual RMS is 1 arcsec, which is the default.
# summary output file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a3_3.0.csv
# output clust2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a3_3.0.csv
# Input file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a3_3.0.txt read successfully to the end.
# Read 14 data lines from image file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/outim_pratchett_ng_a3_3.0.txt
# Read 12 data lines from paired detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/pairdets_pratchett_ng_a3_3.0.csv
# Read 0 data lines from cluster summary file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/sum_pratchett_ng_a3_3.0.csv
# Read 0 data lines from cluster-to-detection file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/clust2det_pratchett_ng_a3_3.0.csv
# Finished creating master cluster summary vector with length 0,
# and master cluster-to-detection vector with length 0
# Launching link_purify()
# Epoch-of-orbit MJD will be used as MJDref, if available.
# Maximum RMS in km: 100000
# Because the cluster-metric exponent for the number of unique points (which is set to -1) and/or
# the corresponding exponent for the number of unique nights (which is set to 1) is negative,
# a special (and recommended) case is triggered in which the cluster metric
# will be the product of the numbers of unique detections on every night that had some detections.
# E.g., an object observed twice per night on three nights would get a metric of 2*2*2 = 8.
# The total timespan will be raised to the power of 0,
# and the astrometric RMS will be raised to the power of (negative) 2
# Duplicate-culled cluster summary vector has length 0,
# Finished loading input clusters: 0 out of 0 passed initial screening.
# Writing 0 lines to output cluster-summary file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLsum_pratchett_ng_a3_3.0.csv
# Writing 0 lines to output clust2det file /home/ellie/research/lsst/sorcha_output/127005pratchett_new/LPLclust2det_pratchett_ng_a3_3.0.csv

# %%
## how many linkages?

a1_links = []
a2_links = []
a3_links = []

for n in range(len(ofnames)):

    if os.path.isfile('{0}LPLsum_{1}.csv'.format(sfpath, ofnames[n])):
        df_links = pd.read_csv('{0}LPLsum_{1}.csv'.format(sfpath, ofnames[n]))
        num_links = len(df_links)

        print(ofnames[n]+' - '+str(num_links))
    else:
        print('{0}LPLsum_{1}.csv does not exist'.format(sfpath, ofnames[n]))
# Out:
# pratchett_cart - 1
# pratchett_ng_a1_-12.0 - 1
# pratchett_ng_a2_-12.0 - 1
# pratchett_ng_a3_-12.0 - 1
# pratchett_ng_a1_-11.0 - 1
# pratchett_ng_a2_-11.0 - 1
# pratchett_ng_a3_-11.0 - 1
# pratchett_ng_a1_-10.0 - 1
# pratchett_ng_a2_-10.0 - 1
# pratchett_ng_a3_-10.0 - 1
# pratchett_ng_a1_-9.0 - 1
# pratchett_ng_a2_-9.0 - 1
# pratchett_ng_a3_-9.0 - 1
# pratchett_ng_a1_-8.0 - 1
# pratchett_ng_a2_-8.0 - 1
# pratchett_ng_a3_-8.0 - 1
# pratchett_ng_a1_-7.0 - 1
# pratchett_ng_a2_-7.0 - 1
# pratchett_ng_a3_-7.0 - 1
# pratchett_ng_a1_-6.0 - 1
# pratchett_ng_a2_-6.0 - 1
# pratchett_ng_a3_-6.0 - 1
# pratchett_ng_a1_-5.0 - 1
# pratchett_ng_a2_-5.0 - 0
# pratchett_ng_a3_-5.0 - 0
# pratchett_ng_a1_-4.0 - 1
# pratchett_ng_a2_-4.0 - 1
# pratchett_ng_a3_-4.0 - 1
# pratchett_ng_a1_-3.0 - 0
# pratchett_ng_a3_-3.0 - 0
# pratchett_ng_a1_-2.0 - 1
# pratchett_ng_a3_-2.0 - 0
# pratchett_ng_a1_-1.0 - 0
# pratchett_ng_a2_-1.0 - 0
# pratchett_ng_a3_-1.0 - 0
# pratchett_ng_a1_0.0 - 0
# pratchett_ng_a3_0.0 - 0
# pratchett_ng_a1_1.0 - 0
# pratchett_ng_a2_1.0 - 0
# pratchett_ng_a3_1.0 - 0
# pratchett_ng_a2_2.0 - 0
# pratchett_ng_a3_2.0 - 0
# pratchett_ng_a3_3.0 - 0
